# %%
data=pd.read_csv('Position_Salaries.csv')
X=dataset.iloc[:,1:-1].values
y=dataset.iloc[:,-1].values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-beef0c0b4b8a> in <module>
# ----> 1 data=pd.read_csv('Position_Salaries.csv')
#       2 X=dataset.iloc[:,1:-1].values
#       3 y=dataset.iloc[:,-1].values
#
# NameError: name 'pd' is not defined

# %%
print(X)

# %%
print(y)#lets convert to 2d shape as standarizaton funtion expect 2D
y=y.reshape(len(y),1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-44c88a79bae6> in <module>
# ----> 1 print(y)#lets convert to 2d shape as standarizaton funtion expect 2D
#       2 y=y.reshape(len(y),1)
#
# NameError: name 'y' is not defined

# %%
from sklearn.preprocessing import standarizaton
sc_X=StandardScaler()
sc_y=StandardScaler()
X=sc_X.fit_transform(X)
y=sc_y.fit_transform(y)

# %%
print(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-fa0134f942c4> in <module>
# ----> 1 print(X)
#
# NameError: name 'X' is not defined

# %%
print(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-d9183e048de3> in <module>
# ----> 1 print(y)
#
# NameError: name 'y' is not defined

# %%
#training the SVR model on whole data (not deviding as train and test)
from sklearn.svm import SVR
regressor=SVR(kernel='rbf')
regressor.fit(X,y)

# %%
sc_y.inverse_transform(regressor.predict(sc_X.fit_transform([[6.5]])).reshape([-1,1]))

# %%
#visualising the SVR
import matplotlib.pyplot as plt
plt.scatter(sc_X.inverse_transform(X),sc_y.inverse_transform(y),color='red')
plt.plot(sc_X.inverse_transform(X),sc_y.inverse_transform(regressor.predict(sc_X)))
plt.title('SVR Model')
