# %%
#Apriori Alogorthum
# !pip install apyori
#import lib
import  numpy as np
import matplotlib.pyplot as plt
import pandas as pd 
#no sklearn as it doesnt have apriori
import apyori
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5976 sha256=828d68e5449075c6feef55d255002f23657d91415a3b5772f92972060fae6635
#   Stored in directory: /root/.cache/pip/wheels/32/2a/54/10c595515f385f3726642b10c60bf788029e8f3a1323e3913a
# Successfully built apyori
# ...

# %%
#Data Preprocessing
dataset=pd.read_csv('Market_Basker_Optimization.csv',head=None)
dataset.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-9feb2874a315> in <cell line: 2>()
#       1 #Data Preprocessing
# ----> 2 dataset=pd.read_csv('MArket_Basker_Optimization.csv')
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
#convert to list of  transactions convertion
transactions=[]
for i in range (0,7501):
  transactions.append([str(dataset.values[i,j]) for j in range(0,20)])

# %%
Displaying the first results com
