# %%
# %%bash
# #pip install gym
# pip install matplotlib-venn

# %%
# %ls
# Out:
# envs.py  sample_data/

# %%
# !pip uninstall gym -y
# !pip install pyglet==1.5.11
# !pip install pyglet
# !pip install gym==0.21.0
import gym
import numpy as np
from IPython import display
from matplotlib import pyplot as plt
import sys
#sys.path.insert(0,'/content')
from envs import Maze
# %matplotlib inline
# Out:
# WARNING: Skipping gym as it is not installed.
# ...
#   Using cached gym-0.21.0.tar.gz (1.5 MB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
import gym

# %%
#initialize the environment

# %%
env=Maze()

# %%
#!pip install gymgrid2
import gymgrid #pip install gymgrid
frmae= env.render(mode='rgb_array')
plt.axis('off')
plt.imhow(frame)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-16-66033d3b0b37> in <cell line: 3>()
#       1 #!pip install gymgrid2
#       2 import gymgrid #pip install gymgrid
# ----> 3 frmae= env.render(mode='rgb_array')
#       4 plt.axis('off')
#       5 plt.imhow(frame)
#
# /content/envs.py in render(self, mode)
#     119
#     120         if self.viewer is None:
# --> 121             from gym.envs.classic_control import rendering
#     122             # First time the environment is rendered.
#     123             self.viewer = rendering.Viewer(screen_size, screen_size)
#
# ModuleNotFoundError: No module named 'gym.envs.classic_control'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# ...

# %%
print('obesrevationspace', {env.obeservation_space.nvec})
print('numbe rof oactions',{env.action_space.n})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-1d3e896b8875> in <cell line: 1>()
# ----> 1 print('obesrevationspace', {env.obeservation_space.nvec})
#       2 print('numbe rof oactions',{env.action_space.n})
#
# NameError: name 'env' is not defined

# %%
## Define the policy pi(.|s)

# %%
#create policy
# Out:
#   File "<ipython-input-7-1ba4b5a70191>", line 1
#     create policy
#            ^
# SyntaxError: invalid syntax

# %%
policy_probs=np.full([5,5,4],0.25)# 25 states with 4 possible actions all with 0.25 probility to choose. [0.25,0.25,0.25,0.25]

# %%
def policy(state):
  return policy_probs[state]

# %%
#Test the policy with state (0,0)

# %%
action_probabilities=policy((0,0))
for action,prob in zip(range(4),action_probabilities):
  print(f"probability of taking all 4 actions at state o",action, prob)
# Out:
# probability of taking all 4 actions at state o 0 0.25
# probability of taking all 4 actions at state o 1 0.25
# probability of taking all 4 actions at state o 2 0.25
# probability of taking all 4 actions at state o 3 0.25

# %%
# See the agent with it
test_agent(env,policy,episodes=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-44dec00f5e8e> in <cell line: 2>()
#       1 # See the agent with it
# ----> 2 test_agent(env,policy,episodes=1)
#
# NameError: name 'test_agent' is not defined

# %%
#plot the policy

# %%
plot_policy(policy_probs,frame)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-d2ba627e5fc2> in <cell line: 1>()
# ----> 1 plot_policy(policy_probs,frame)
#
# NameError: name 'plot_policy' is not defined

# %%
#bDefine value table V(s)

# %%
#create the Vs(s)
state_values=np.zeros(shape-[5,5])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-80c467e2c536> in <cell line: 2>()
#       1 #create the Vs(s)
# ----> 2 state_values=np.zeros(shape-[5,5])
#
# NameError: name 'shape' is not defined

# %%
#plot V(s)
plot_values(state_values,frame)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-6568e93bd1e1> in <cell line: 2>()
#       1 #plot V(s)
# ----> 2 plot_values(state_values,frame)
#
# NameError: name 'plot_values' is not defined

# %%
##Implement the value iteration algorithum

# %%
def value_iteration(policy_probs,state_values,theta=1e-6,gamma=0.99):
  delta=float('inf')
  while delta >delta:
    delta=0
    for row in range(5):
      old_value = state_values[()]

      #do this later from video
