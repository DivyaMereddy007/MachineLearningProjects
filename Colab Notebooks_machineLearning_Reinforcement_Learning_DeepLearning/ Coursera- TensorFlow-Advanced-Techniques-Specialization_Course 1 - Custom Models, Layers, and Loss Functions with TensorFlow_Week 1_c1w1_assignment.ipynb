# %%
#for data sets clone above 
# !git clone https://github.com/ashishpatel26/TensorFlow-Advanced-Techniques-Specialization.git
import sys
sys.path.append('/content/TensorFlow-Advanced-Techniques-Specialization/Course 1 - Custom Models, Layers, and Loss Functions with TensorFlow/Week 1/')


import pandas as pd
import numpy as np
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf
import keras
from keras.layers import Activation, Dense
# Please uncomment all lines in this cell and replace those marked with `# YOUR CODE HERE`.
# You can select all lines in this code cell with Ctrl+A (Windows/Linux) or Cmd+A (Mac), then press Ctrl+/ (Windows/Linux) or Cmd+/ (Mac) to uncomment.

# URL of the white wine dataset
URL = 'http://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv'

# load the dataset from the URL
white_df = pd.read_csv(URL, sep=";")

# fill the `is_red` column with zeros.
white_df["is_red"] = 0

# keep only the first of duplicate items
white_df = white_df.drop_duplicates(keep='first')
# Out:
# fatal: destination path 'TensorFlow-Advanced-Techniques-Specialization' already exists and is not an empty directory.

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import itertools

import utils

# %%
import utils
utils.test_white_df(white_df)
# Out:
#  All public tests passed

# %%
# URL of the red wine dataset
URL = 'http://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv'

# load the dataset from the URL
red_df = pd.read_csv(URL, sep=";")

# fill the `is_red` column with ones.
red_df["is_red"] = 1

# keep only the first of duplicate items
red_df = red_df.drop_duplicates(keep='first')

# %%
utils.test_red_df(red_df)
# Out:
#  All public tests passed

# %%
print(red_df.alcohol[0])
print(red_df.alcohol[100])

# EXPECTED OUTPUT
# 9.4
# 10.2
# Out:
# 9.4
# 10.2

# %%
#Concatenate the datasets

df = pd.concat([red_df, white_df], ignore_index=True)
print(df.alcohol[0])
print(df.alcohol[100])

# EXPECTED OUTPUT
# 9.4
# 9.5
# Out:
# 9.4
# 9.5

# %%
# NOTE: In a real-world scenario, you should shuffle the data.
# YOU ARE NOT going to do that here because we want to test
# with deterministic data. But if you want the code to do it,
# it's in the commented line below:

#df = df.iloc[np.random.permutation(len(df))]

# %%
df['quality'].hist(bins=20);

# %%
# Please uncomment all lines in this cell and replace those marked with `# YOUR CODE HERE`.
# You can select all lines in this code cell with Ctrl+A (Windows/Linux) or Cmd+A (Mac), then press Ctrl+/ (Windows/Linux) or Cmd+/ (Mac) to uncomment.

# get data with wine quality greater than 4 and less than 8
df = df[(df['quality'] > 4) & (df['quality'] < 8 )]

# reset index and drop the old one
df = df.reset_index(drop=True)

# %%
utils.test_df_drop(df)
# Out:
#  All public tests passed

# %%
df['quality'].hist(bins=20);

# %%
# Train Test Split (TODO)
# Next, you can split the datasets into training, test and validation datasets.

# The data frame should be split 80:20 into train and test sets.
# The resulting train should then be split 80:20 into train and val sets.
# The train_test_split parameter test_size takes a float value that ranges between 0. and 1, and represents the proportion of the dataset that is allocated to the test set. The rest of the data is allocated to the training set.

# %%
# Please uncomment all lines in this cell and replace those marked with `# YOUR CODE HERE`.
# You can select all lines in this code cell with Ctrl+A (Windows/Linux) or Cmd+A (Mac), then press Ctrl+/ (Windows/Linux) or Cmd+/ (Mac) to uncomment.


# Please do not change the random_state parameter. This is needed for grading.

# split df into 80:20 train and test sets
train, test = train_test_split(df, test_size=0.2, random_state = 1)
                               
# split train into 80:20 train and val sets
train, val = train_test_split(train, test_size=0.2, random_state = 1)

# %%
utils.test_data_sizes(train.size, test.size, val.size)
# Out:
#  All public tests passed

# %%
train_stats = train.describe()
train_stats.pop('is_red')
train_stats.pop('quality')
train_stats = train_stats.transpose()

# %%
train_stats
# Out:
#                        count        mean        std      min       25%  \
# fixed acidity         3155.0    7.221616   1.325297  3.80000   6.40000
# volatile acidity      3155.0    0.338929   0.162476  0.08000   0.23000
# citric acid           3155.0    0.321569   0.147970  0.00000   0.25000
# residual sugar        3155.0    5.155911   4.639632  0.60000   1.80000
# chlorides             3155.0    0.056976   0.036802  0.01200   0.03800
# free sulfur dioxide   3155.0   30.388590  17.236784  1.00000  17.00000
# total sulfur dioxide  3155.0  115.062282  56.706617  6.00000  75.00000
# density               3155.0    0.994633   0.003005  0.98711   0.99232
# pH                    3155.0    3.223201   0.161272  2.72000   3.11000
# sulphates             3155.0    0.534051   0.149149  0.22000   0.43000
# alcohol               3155.0   10.504466   1.154654  8.50000   9.50000
#
#                             50%       75%        max
# fixed acidity           7.00000    7.7000   15.60000
# volatile acidity        0.29000    0.4000    1.24000
# citric acid             0.31000    0.4000    1.66000
# residual sugar          2.80000    7.6500   65.80000
# chlorides               0.04700    0.0660    0.61100
# free sulfur dioxide    28.00000   41.0000  131.00000
# total sulfur dioxide  117.00000  156.0000  344.00000
# density                 0.99481    0.9968    1.03898
# pH                      3.21000    3.3300    4.01000
# sulphates               0.51000    0.6000    1.95000
# alcohol                10.30000   11.3000   14.00000

# %%
# Get the labels (TODO)
# The features and labels are currently in the same dataframe.

# You will want to store the label columns is_red and quality separately from the feature columns.
# The following function, format_output, gets these two columns from the dataframe (it's given to you).
# format_output also formats the data into numpy arrays.
# Please use the format_output and apply it to the train, val and test sets to get dataframes for the labels.

# %%
def format_output(data):
    is_red = data.pop('is_red')
    is_red = np.array(is_red)
    quality = data.pop('quality')
    quality = np.array(quality)
    return (quality, is_red)

# %%
# Please uncomment all lines in this cell and replace those marked with `# YOUR CODE HERE`.
# You can select all lines in this code cell with Ctrl+A (Windows/Linux) or Cmd+A (Mac), then press Ctrl+/ (Windows/Linux) or Cmd+/ (Mac) to uncomment.


# format the output of the train set
train_Y = format_output(train)

# format the output of the val set
val_Y = format_output(val)
    
# format the output of the test set
test_Y = format_output(test)

# %%
utils.test_format_output(df, train_Y, val_Y, test_Y)
# Out:
#  All public tests passed

# %%
train.head()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 225             7.5              0.65         0.18             7.0      0.088
# 3557            6.3              0.27         0.29            12.2      0.044
# 3825            8.8              0.27         0.25             5.0      0.024
# 1740            6.4              0.45         0.07             1.1      0.030
# 1221            7.2              0.53         0.13             2.0      0.058
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 225                  27.0                  94.0  0.99915  3.38       0.77
# 3557                 59.0                 196.0  0.99782  3.14       0.40
# 3825                 52.0                  99.0  0.99250  2.87       0.49
# 1740                 10.0                 131.0  0.99050  2.97       0.28
# 1221                 18.0                  22.0  0.99573  3.21       0.68
#
#       alcohol
# 225       9.4
# 3557      8.8
# 3825     11.4
# 1740     10.8
# 1221      9.9

# %%
def norm(x):
    return (x - train_stats['mean']) / train_stats['std']

# %%
# Please uncomment all lines in this cell and replace those marked with `# YOUR CODE HERE`.
# You can select all lines in this code cell with Ctrl+A (Windows/Linux) or Cmd+A (Mac), then press Ctrl+/ (Windows/Linux) or Cmd+/ (Mac) to uncomment.

# normalize the train set
norm_train_X = norm(train)
    
# normalize the val set
norm_val_X = norm(val)
    
# normalize the test set
norm_test_X = norm(test)

# %%
utils.test_norm(norm_train_X, norm_val_X, norm_test_X, train, val, test)
# Out:
#  All public tests passed

# %%
# Define the Model (TODO)
# Define the model using the functional API. The base model will be 2 Dense layers of 128 neurons each, and have the 'relu' activation.

# Check out the documentation for tf.keras.layers.Dense

# %%
# Please uncomment all lines in this cell and replace those marked with `# YOUR CODE HERE`.
# You can select all lines in this code cell with Ctrl+A (Windows/Linux) or Cmd+A (Mac), then press Ctrl+/ (Windows/Linux) or Cmd+/ (Mac) to uncomment.


def base_model(inputs):
    
    # connect a Dense layer with 128 neurons and a relu activation
    x = tf.keras.layers.Dense(128, activation= "relu")(inputs)
    
    # connect another Dense layer with 128 neurons and a relu activation
    x = tf.keras.layers.Dense(128, activation= "relu")(x)
    return x

# %%
utils.test_base_model(base_model)
# Out:
# return_type_check: Return type is incorrect. Please check implementation.
# Expected: <class 'tensorflow.python.framework.ops.Tensor'>
# Result: <class 'keras.engine.keras_tensor.KerasTensor'>
# Please open utils.py if you want to see the unit test here.
#
#  5  Tests passed
#  1  Tests failed
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-70-468cefd178cd> in <cell line: 1>()
# ----> 1 utils.test_base_model(base_model)
#
# /content/TensorFlow-Advanced-Techniques-Specialization/Course 1 - Custom Models, Layers, and Loss Functions with TensorFlow/Week 1/utils.py in test_base_model(base_model)
#     257     ]
#     258
# --> 259     test_loop(test_cases)
#     260
#     261 def test_final_model(final_model):
#
# /content/TensorFlow-Advanced-Techniques-Specialization/Course 1 - Custom Models, Layers, and Loss Functions with TensorFlow/Week 1/utils.py in test_loop(test_cases)
#      25         print('\033', success," Tests passed")
#      26         print('\033', fails, " Tests failed")
# ---> 27         raise Exception(test_case["error_message"])
#      28
#      29 def test_white_df(white_df):
#
# Exception: Output layer type is incorrect. Please check implementation.

# %%
base_model
# Out:
# <function __main__.base_model(inputs)>

# %%
# #Define output layers of the model (TODO)

# You will add output layers to the base model.

# The model will need two outputs.
# One output layer will predict wine quality, which is a numeric value.

# Define a Dense layer with 1 neuron.
# Since this is a regression output, the activation can be left as its default value None.
# The other output layer will predict the wine type, which is either red 1 or not red 0 (white).

# Define a Dense layer with 1 neuron.
# Since there are two possible categories, you can use a sigmoid activation for binary classification.
# Define the Model

# Define the Model object, and set the following parameters:
# inputs: pass in the inputs to the model as a list.
# outputs: pass in a list of the outputs that you just defined: wine quality, then wine type.
# Note: please list the wine quality before wine type in the outputs, as this will affect the calculated loss if you choose the other order.

# %%
# Please uncomment all lines in this cell and replace those marked with `# YOUR CODE HERE`.
# You can select all lines in this code cell with Ctrl+A (Windows/Linux) or Cmd+A (Mac), then press Ctrl+/ (Windows/Linux) or Cmd+/ (Mac) to uncomment.



def final_model(inputs):
    
    # get the base model
    x = base_model(inputs)

    # connect the output Dense layer for regression
    wine_quality = Dense(units='1', name='wine_quality')(x)

    # connect the output Dense layer for classification. this will use a sigmoid activation.
    wine_type = Dense(units='1', activation='sigmoid', name='wine_type')(x)

    # define the model using the input and output layers
    model = Model(inputs=inputs, outputs=[wine_quality, wine_type])

    return model

# %%
utils.test_final_model(final_model)
# Out:
# return_type_check: Return type is incorrect. Please check implementation.
# Expected: <class 'keras.engine.training.Model'>
# Result: <class 'keras.engine.functional.Functional'>
# Please open utils.py if you want to see the unit test here.
#
#  1  Tests passed
#  1  Tests failed
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-72-627ff8303ae7> in <cell line: 1>()
# ----> 1 utils.test_final_model(final_model)
#
# /content/TensorFlow-Advanced-Techniques-Specialization/Course 1 - Custom Models, Layers, and Loss Functions with TensorFlow/Week 1/utils.py in test_final_model(final_model)
#     279     ]
#     280
# --> 281     test_loop(test_cases)
#     282
#     283 def test_model_compile(model):
#
# /content/TensorFlow-Advanced-Techniques-Specialization/Course 1 - Custom Models, Layers, and Loss Functions with TensorFlow/Week 1/utils.py in test_loop(test_cases)
#      25         print('\033', success," Tests passed")
#      26         print('\033', fails, " Tests failed")
# ---> 27         raise Exception(test_case["error_message"])
#      28
#      29 def test_white_df(white_df):
#
# Exception: wine_quality layer has an incorrect activation. Please check implementation.

# %%
"""
Compiling the Model
Next, compile the model. When setting the loss parameter of model.compile, you're setting the loss for each of the two outputs (wine quality and wine type).

To set more than one loss, use a dictionary of key-value pairs.

You can look at the docs for the losses here.
Note: For the desired spelling, please look at the "Functions" section of the documentation and not the "classes" section on that same page.
wine_type: Since you will be performing binary classification on wine type, you should use the binary crossentropy loss function for it. Please pass this in as a string.
Hint, this should be all lowercase. In the documentation, you'll see this under the "Functions" section, not the "Classes" section.
wine_quality: since this is a regression output, use the mean squared error. Please pass it in as a string, all lowercase.
Hint: You may notice that there are two aliases for mean squared error. Please use the shorter name.
You will also set the metric for each of the two outputs. Again, to set metrics for two or more outputs, use a dictionary with key value pairs.

The metrics documentation is linked here.
For the wine type, please set it to accuracy as a string, all lowercase.
For wine quality, please use the root mean squared error. Instead of a string, you'll set it to an instance of the class RootMeanSquaredError, which belongs to the tf.keras.metrics module.
Note: If you see the error message

Exception: wine quality loss function is incorrect.

Please also check your other losses and metrics, as the error may be caused by the other three key-value pairs and not the wine quality loss.
"""
# Out:
# '\nCompiling the Model\nNext, compile the model. When setting the loss parameter of model.compile, you\'re setting the loss for each of the two outputs (wine quality and wine type).\n\nTo set more than one loss, use a dictionary of key-value pairs.\n\nYou can look at the docs for the losses here.\nNote: For the desired spelling, please look at the "Functions" section of the documentation and not the "classes" section on that same page.\nwine_type: Since you will be performing binary classification on wine type, you should use the binary crossentropy loss function for it. Please pass this in as a string.\nHint, this should be all lowercase. In the documentation, you\'ll see this under the "Functions" section, not the "Classes" section.\nwine_quality: since this is a regression output, use the mean squared error. Please pass it in as a string, all lowercase.\nHint: You may notice that there are two aliases for mean squared error. Please use the shorter name.\nYou will also set the metric for each of the two outputs. Again, to set metrics for two or more outputs, use a dictionary with key value pairs.\n\nThe metrics documentation is linked here.\nFor the wine type, please set it to accuracy as a string, all lowercase.\nFor wine quality, please use the root mean squared error. Instead of a string, you\'ll set it to an instance of the class RootMeanSquaredError, which belongs to the tf.keras.metrics module.\nNote: If you see the error message\n\nException: wine quality loss function is incorrect.\n\nPlease also check your other losses and metrics, as the error may be caused by the other three key-value pairs and not the wine quality loss.\n'

# %%
# Please uncomment all lines in this cell and replace those marked with `# YOUR CODE HERE`.
# You can select all lines in this code cell with Ctrl+A (Windows/Linux) or Cmd+A (Mac), then press Ctrl+/ (Windows/Linux) or Cmd+/ (Mac) to uncomment.


inputs = tf.keras.layers.Input(shape=(11,))
rms = tf.keras.optimizers.RMSprop(learning_rate=0.0001)
model = final_model(inputs)

model.compile(optimizer=rms, 
              loss = {'wine_type' : 'binary_crossentropy',
                      'wine_quality' : 'mean_squared_error'
                     },
              metrics = {'wine_type' : 'accuracy',
                         'wine_quality': tf.keras.metrics.RootMeanSquaredError()
                       }
             )

# %%
###Training the Model

# %%
## Please uncomment all lines in this cell and replace those marked with `# YOUR CODE HERE`.
## You can select all lines in this code cell with Ctrl+A (Windows/Linux) or Cmd+A (Mac), then press Ctrl+/ (Windows/Linux) or Cmd+/ (Mac) to uncomment.



history = model.fit(norm_train_X, train_Y,
                    epochs = 180, validation_data=(norm_val_X, val_Y))
# Out:
# Epoch 1/180
# 99/99 [==============================] - 3s 10ms/step - loss: 28.7044 - wine_quality_loss: 28.0485 - wine_type_loss: 0.6560 - wine_quality_root_mean_squared_error: 5.2961 - wine_type_accuracy: 0.5151 - val_loss: 20.5635 - val_wine_quality_loss: 19.9594 - val_wine_type_loss: 0.6041 - val_wine_quality_root_mean_squared_error: 4.4676 - val_wine_type_accuracy: 0.7883
# Epoch 2/180
# 99/99 [==============================] - 0s 2ms/step - loss: 13.9135 - wine_quality_loss: 13.3553 - wine_type_loss: 0.5582 - wine_quality_root_mean_squared_error: 3.6545 - wine_type_accuracy: 0.9246 - val_loss: 8.3268 - val_wine_quality_loss: 7.8099 - val_wine_type_loss: 0.5169 - val_wine_quality_root_mean_squared_error: 2.7946 - val_wine_type_accuracy: 0.9518
# Epoch 3/180
# 99/99 [==============================] - 0s 2ms/step - loss: 5.0539 - wine_quality_loss: 4.5850 - wine_type_loss: 0.4689 - wine_quality_root_mean_squared_error: 2.1413 - wine_type_accuracy: 0.9261 - val_loss: 3.0322 - val_wine_quality_loss: 2.6027 - val_wine_type_loss: 0.4295 - val_wine_quality_root_mean_squared_error: 1.6133 - val_wine_type_accuracy: 0.8999
# Epoch 4/180
# 99/99 [==============================] - 0s 2ms/step - loss: 2.6922 - wine_quality_loss: 2.3128 - wine_type_loss: 0.3794 - wine_quality_root_mean_squared_error: 1.5208 - wine_type_accuracy: 0.9046 - val_loss: 2.3632 - val_wine_quality_loss: 2.0183 - val_wine_type_loss: 0.3449 - val_wine_quality_root_mean_squared_error: 1.4207 - val_wine_type_accuracy: 0.9214
# Epoch 5/180
# 99/99 [==============================] - 0s 3ms/step - loss: 2.2669 - wine_quality_loss: 1.9611 - wine_type_loss: 0.3058 - wine_quality_root_mean_squared_error: 1.4004 - wine_type_accuracy: 0.9372 - val_loss: 2.1005 - val_wine_quality_loss: 1.8216 - val_wine_type_loss: 0.2789 - val_wine_quality_root_mean_squared_error: 1.3497 - val_wine_type_accuracy: 0.9531
# Epoch 6/180
# 99/99 [==============================] - 0s 2ms/step - loss: 2.0175 - wine_quality_loss: 1.7704 - wine_type_loss: 0.2470 - wine_quality_root_mean_squared_error: 1.3306 - wine_type_accuracy: 0.9632 - val_loss: 1.8949 - val_wine_quality_loss: 1.6709 - val_wine_type_loss: 0.2240 - val_wine_quality_root_mean_squared_error: 1.2926 - val_wine_type_accuracy: 0.9785
# Epoch 7/180
# 99/99 [==============================] - 0s 2ms/step - loss: 1.8038 - wine_quality_loss: 1.6067 - wine_type_loss: 0.1971 - wine_quality_root_mean_squared_error: 1.2676 - wine_type_accuracy: 0.9724 - val_loss: 1.7187 - val_wine_quality_loss: 1.5399 - val_wine_type_loss: 0.1788 - val_wine_quality_root_mean_squared_error: 1.2409 - val_wine_type_accuracy: 0.9823
# Epoch 8/180
# 99/99 [==============================] - 0s 2ms/step - loss: 1.6463 - wine_quality_loss: 1.4859 - wine_type_loss: 0.1604 - wine_quality_root_mean_squared_error: 1.2190 - wine_type_accuracy: 0.9816 - val_loss: 1.5829 - val_wine_quality_loss: 1.4377 - val_wine_type_loss: 0.1452 - val_wine_quality_root_mean_squared_error: 1.1990 - val_wine_type_accuracy: 0.9823
# Epoch 9/180
# 99/99 [==============================] - 0s 2ms/step - loss: 1.5148 - wine_quality_loss: 1.3823 - wine_type_loss: 0.1325 - wine_quality_root_mean_squared_error: 1.1757 - wine_type_accuracy: 0.9861 - val_loss: 1.4580 - val_wine_quality_loss: 1.3376 - val_wine_type_loss: 0.1204 - val_wine_quality_root_mean_squared_error: 1.1565 - val_wine_type_accuracy: 0.9848
# Epoch 10/180
# 99/99 [==============================] - 0s 3ms/step - loss: 1.4039 - wine_quality_loss: 1.2928 - wine_type_loss: 0.1111 - wine_quality_root_mean_squared_error: 1.1370 - wine_type_accuracy: 0.9880 - val_loss: 1.3697 - val_wine_quality_loss: 1.2697 - val_wine_type_loss: 0.1000 - val_wine_quality_root_mean_squared_error: 1.1268 - val_wine_type_accuracy: 0.9911
# Epoch 11/180
# 99/99 [==============================] - 0s 2ms/step - loss: 1.3017 - wine_quality_loss: 1.2072 - wine_type_loss: 0.0945 - wine_quality_root_mean_squared_error: 1.0987 - wine_type_accuracy: 0.9886 - val_loss: 1.2530 - val_wine_quality_loss: 1.1674 - val_wine_type_loss: 0.0855 - val_wine_quality_root_mean_squared_error: 1.0805 - val_wine_type_accuracy: 0.9911
# Epoch 12/180
# 99/99 [==============================] - 0s 2ms/step - loss: 1.2179 - wine_quality_loss: 1.1356 - wine_type_loss: 0.0823 - wine_quality_root_mean_squared_error: 1.0656 - wine_type_accuracy: 0.9895 - val_loss: 1.1930 - val_wine_quality_loss: 1.1187 - val_wine_type_loss: 0.0743 - val_wine_quality_root_mean_squared_error: 1.0577 - val_wine_type_accuracy: 0.9911
# Epoch 13/180
# 99/99 [==============================] - 0s 3ms/step - loss: 1.1415 - wine_quality_loss: 1.0681 - wine_type_loss: 0.0734 - wine_quality_root_mean_squared_error: 1.0335 - wine_type_accuracy: 0.9905 - val_loss: 1.1026 - val_wine_quality_loss: 1.0361 - val_wine_type_loss: 0.0664 - val_wine_quality_root_mean_squared_error: 1.0179 - val_wine_type_accuracy: 0.9911
# Epoch 14/180
# 99/99 [==============================] - 0s 3ms/step - loss: 1.0729 - wine_quality_loss: 1.0063 - wine_type_loss: 0.0667 - wine_quality_root_mean_squared_error: 1.0031 - wine_type_accuracy: 0.9902 - val_loss: 1.0408 - val_wine_quality_loss: 0.9809 - val_wine_type_loss: 0.0599 - val_wine_quality_root_mean_squared_error: 0.9904 - val_wine_type_accuracy: 0.9911
# Epoch 15/180
# 99/99 [==============================] - 0s 2ms/step - loss: 1.0105 - wine_quality_loss: 0.9493 - wine_type_loss: 0.0612 - wine_quality_root_mean_squared_error: 0.9743 - wine_type_accuracy: 0.9905 - val_loss: 0.9882 - val_wine_quality_loss: 0.9335 - val_wine_type_loss: 0.0547 - val_wine_quality_root_mean_squared_error: 0.9662 - val_wine_type_accuracy: 0.9911
# Epoch 16/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.9526 - wine_quality_loss: 0.8957 - wine_type_loss: 0.0568 - wine_quality_root_mean_squared_error: 0.9464 - wine_type_accuracy: 0.9902 - val_loss: 0.9283 - val_wine_quality_loss: 0.8776 - val_wine_type_loss: 0.0507 - val_wine_quality_root_mean_squared_error: 0.9368 - val_wine_type_accuracy: 0.9911
# Epoch 17/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.8982 - wine_quality_loss: 0.8448 - wine_type_loss: 0.0534 - wine_quality_root_mean_squared_error: 0.9191 - wine_type_accuracy: 0.9905 - val_loss: 0.8833 - val_wine_quality_loss: 0.8358 - val_wine_type_loss: 0.0475 - val_wine_quality_root_mean_squared_error: 0.9142 - val_wine_type_accuracy: 0.9911
# Epoch 18/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.8528 - wine_quality_loss: 0.8023 - wine_type_loss: 0.0505 - wine_quality_root_mean_squared_error: 0.8957 - wine_type_accuracy: 0.9908 - val_loss: 0.8401 - val_wine_quality_loss: 0.7952 - val_wine_type_loss: 0.0449 - val_wine_quality_root_mean_squared_error: 0.8917 - val_wine_type_accuracy: 0.9924
# Epoch 19/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.8085 - wine_quality_loss: 0.7603 - wine_type_loss: 0.0482 - wine_quality_root_mean_squared_error: 0.8720 - wine_type_accuracy: 0.9908 - val_loss: 0.8014 - val_wine_quality_loss: 0.7587 - val_wine_type_loss: 0.0428 - val_wine_quality_root_mean_squared_error: 0.8710 - val_wine_type_accuracy: 0.9924
# Epoch 20/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.7668 - wine_quality_loss: 0.7206 - wine_type_loss: 0.0462 - wine_quality_root_mean_squared_error: 0.8489 - wine_type_accuracy: 0.9911 - val_loss: 0.7540 - val_wine_quality_loss: 0.7129 - val_wine_type_loss: 0.0411 - val_wine_quality_root_mean_squared_error: 0.8443 - val_wine_type_accuracy: 0.9937
# Epoch 21/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.7304 - wine_quality_loss: 0.6860 - wine_type_loss: 0.0445 - wine_quality_root_mean_squared_error: 0.8282 - wine_type_accuracy: 0.9921 - val_loss: 0.7238 - val_wine_quality_loss: 0.6843 - val_wine_type_loss: 0.0395 - val_wine_quality_root_mean_squared_error: 0.8272 - val_wine_type_accuracy: 0.9937
# Epoch 22/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.6951 - wine_quality_loss: 0.6522 - wine_type_loss: 0.0430 - wine_quality_root_mean_squared_error: 0.8076 - wine_type_accuracy: 0.9921 - val_loss: 0.6833 - val_wine_quality_loss: 0.6452 - val_wine_type_loss: 0.0382 - val_wine_quality_root_mean_squared_error: 0.8032 - val_wine_type_accuracy: 0.9937
# Epoch 23/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.6639 - wine_quality_loss: 0.6223 - wine_type_loss: 0.0416 - wine_quality_root_mean_squared_error: 0.7889 - wine_type_accuracy: 0.9921 - val_loss: 0.6479 - val_wine_quality_loss: 0.6108 - val_wine_type_loss: 0.0370 - val_wine_quality_root_mean_squared_error: 0.7816 - val_wine_type_accuracy: 0.9937
# Epoch 24/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.6318 - wine_quality_loss: 0.5913 - wine_type_loss: 0.0405 - wine_quality_root_mean_squared_error: 0.7690 - wine_type_accuracy: 0.9924 - val_loss: 0.6261 - val_wine_quality_loss: 0.5900 - val_wine_type_loss: 0.0361 - val_wine_quality_root_mean_squared_error: 0.7681 - val_wine_type_accuracy: 0.9949
# Epoch 25/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.6035 - wine_quality_loss: 0.5641 - wine_type_loss: 0.0395 - wine_quality_root_mean_squared_error: 0.7511 - wine_type_accuracy: 0.9927 - val_loss: 0.5960 - val_wine_quality_loss: 0.5607 - val_wine_type_loss: 0.0353 - val_wine_quality_root_mean_squared_error: 0.7488 - val_wine_type_accuracy: 0.9949
# Epoch 26/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.5761 - wine_quality_loss: 0.5374 - wine_type_loss: 0.0387 - wine_quality_root_mean_squared_error: 0.7331 - wine_type_accuracy: 0.9927 - val_loss: 0.5626 - val_wine_quality_loss: 0.5279 - val_wine_type_loss: 0.0347 - val_wine_quality_root_mean_squared_error: 0.7265 - val_wine_type_accuracy: 0.9949
# Epoch 27/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.5522 - wine_quality_loss: 0.5143 - wine_type_loss: 0.0379 - wine_quality_root_mean_squared_error: 0.7172 - wine_type_accuracy: 0.9927 - val_loss: 0.5463 - val_wine_quality_loss: 0.5124 - val_wine_type_loss: 0.0339 - val_wine_quality_root_mean_squared_error: 0.7158 - val_wine_type_accuracy: 0.9949
# Epoch 28/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.5325 - wine_quality_loss: 0.4954 - wine_type_loss: 0.0371 - wine_quality_root_mean_squared_error: 0.7038 - wine_type_accuracy: 0.9927 - val_loss: 0.5172 - val_wine_quality_loss: 0.4838 - val_wine_type_loss: 0.0335 - val_wine_quality_root_mean_squared_error: 0.6956 - val_wine_type_accuracy: 0.9949
# Epoch 29/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.5124 - wine_quality_loss: 0.4759 - wine_type_loss: 0.0365 - wine_quality_root_mean_squared_error: 0.6899 - wine_type_accuracy: 0.9927 - val_loss: 0.4975 - val_wine_quality_loss: 0.4645 - val_wine_type_loss: 0.0330 - val_wine_quality_root_mean_squared_error: 0.6815 - val_wine_type_accuracy: 0.9949
# Epoch 30/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.4937 - wine_quality_loss: 0.4578 - wine_type_loss: 0.0359 - wine_quality_root_mean_squared_error: 0.6766 - wine_type_accuracy: 0.9927 - val_loss: 0.4876 - val_wine_quality_loss: 0.4550 - val_wine_type_loss: 0.0326 - val_wine_quality_root_mean_squared_error: 0.6745 - val_wine_type_accuracy: 0.9949
# Epoch 31/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.4772 - wine_quality_loss: 0.4419 - wine_type_loss: 0.0353 - wine_quality_root_mean_squared_error: 0.6647 - wine_type_accuracy: 0.9927 - val_loss: 0.4753 - val_wine_quality_loss: 0.4430 - val_wine_type_loss: 0.0323 - val_wine_quality_root_mean_squared_error: 0.6656 - val_wine_type_accuracy: 0.9949
# Epoch 32/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.4626 - wine_quality_loss: 0.4278 - wine_type_loss: 0.0348 - wine_quality_root_mean_squared_error: 0.6540 - wine_type_accuracy: 0.9927 - val_loss: 0.4665 - val_wine_quality_loss: 0.4345 - val_wine_type_loss: 0.0319 - val_wine_quality_root_mean_squared_error: 0.6592 - val_wine_type_accuracy: 0.9949
# Epoch 33/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.4498 - wine_quality_loss: 0.4154 - wine_type_loss: 0.0343 - wine_quality_root_mean_squared_error: 0.6445 - wine_type_accuracy: 0.9927 - val_loss: 0.4441 - val_wine_quality_loss: 0.4123 - val_wine_type_loss: 0.0318 - val_wine_quality_root_mean_squared_error: 0.6421 - val_wine_type_accuracy: 0.9962
# Epoch 34/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.4369 - wine_quality_loss: 0.4030 - wine_type_loss: 0.0339 - wine_quality_root_mean_squared_error: 0.6349 - wine_type_accuracy: 0.9930 - val_loss: 0.4325 - val_wine_quality_loss: 0.4011 - val_wine_type_loss: 0.0314 - val_wine_quality_root_mean_squared_error: 0.6333 - val_wine_type_accuracy: 0.9962
# Epoch 35/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.4265 - wine_quality_loss: 0.3931 - wine_type_loss: 0.0334 - wine_quality_root_mean_squared_error: 0.6270 - wine_type_accuracy: 0.9930 - val_loss: 0.4194 - val_wine_quality_loss: 0.3884 - val_wine_type_loss: 0.0310 - val_wine_quality_root_mean_squared_error: 0.6232 - val_wine_type_accuracy: 0.9962
# Epoch 36/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.4165 - wine_quality_loss: 0.3835 - wine_type_loss: 0.0331 - wine_quality_root_mean_squared_error: 0.6192 - wine_type_accuracy: 0.9930 - val_loss: 0.4114 - val_wine_quality_loss: 0.3806 - val_wine_type_loss: 0.0307 - val_wine_quality_root_mean_squared_error: 0.6169 - val_wine_type_accuracy: 0.9962
# Epoch 37/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.4081 - wine_quality_loss: 0.3755 - wine_type_loss: 0.0326 - wine_quality_root_mean_squared_error: 0.6128 - wine_type_accuracy: 0.9930 - val_loss: 0.4064 - val_wine_quality_loss: 0.3757 - val_wine_type_loss: 0.0306 - val_wine_quality_root_mean_squared_error: 0.6130 - val_wine_type_accuracy: 0.9962
# Epoch 38/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3998 - wine_quality_loss: 0.3675 - wine_type_loss: 0.0323 - wine_quality_root_mean_squared_error: 0.6062 - wine_type_accuracy: 0.9930 - val_loss: 0.4030 - val_wine_quality_loss: 0.3725 - val_wine_type_loss: 0.0305 - val_wine_quality_root_mean_squared_error: 0.6103 - val_wine_type_accuracy: 0.9962
# Epoch 39/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3939 - wine_quality_loss: 0.3620 - wine_type_loss: 0.0319 - wine_quality_root_mean_squared_error: 0.6016 - wine_type_accuracy: 0.9930 - val_loss: 0.3934 - val_wine_quality_loss: 0.3630 - val_wine_type_loss: 0.0304 - val_wine_quality_root_mean_squared_error: 0.6025 - val_wine_type_accuracy: 0.9962
# Epoch 40/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3892 - wine_quality_loss: 0.3576 - wine_type_loss: 0.0316 - wine_quality_root_mean_squared_error: 0.5980 - wine_type_accuracy: 0.9930 - val_loss: 0.3877 - val_wine_quality_loss: 0.3575 - val_wine_type_loss: 0.0303 - val_wine_quality_root_mean_squared_error: 0.5979 - val_wine_type_accuracy: 0.9962
# Epoch 41/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3819 - wine_quality_loss: 0.3505 - wine_type_loss: 0.0313 - wine_quality_root_mean_squared_error: 0.5921 - wine_type_accuracy: 0.9933 - val_loss: 0.3846 - val_wine_quality_loss: 0.3546 - val_wine_type_loss: 0.0299 - val_wine_quality_root_mean_squared_error: 0.5955 - val_wine_type_accuracy: 0.9949
# Epoch 42/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3766 - wine_quality_loss: 0.3456 - wine_type_loss: 0.0310 - wine_quality_root_mean_squared_error: 0.5879 - wine_type_accuracy: 0.9930 - val_loss: 0.3788 - val_wine_quality_loss: 0.3491 - val_wine_type_loss: 0.0298 - val_wine_quality_root_mean_squared_error: 0.5908 - val_wine_type_accuracy: 0.9949
# Epoch 43/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3728 - wine_quality_loss: 0.3421 - wine_type_loss: 0.0307 - wine_quality_root_mean_squared_error: 0.5849 - wine_type_accuracy: 0.9933 - val_loss: 0.3758 - val_wine_quality_loss: 0.3461 - val_wine_type_loss: 0.0297 - val_wine_quality_root_mean_squared_error: 0.5883 - val_wine_type_accuracy: 0.9949
# Epoch 44/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3685 - wine_quality_loss: 0.3380 - wine_type_loss: 0.0305 - wine_quality_root_mean_squared_error: 0.5814 - wine_type_accuracy: 0.9933 - val_loss: 0.3758 - val_wine_quality_loss: 0.3462 - val_wine_type_loss: 0.0296 - val_wine_quality_root_mean_squared_error: 0.5884 - val_wine_type_accuracy: 0.9949
# Epoch 45/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3640 - wine_quality_loss: 0.3339 - wine_type_loss: 0.0302 - wine_quality_root_mean_squared_error: 0.5778 - wine_type_accuracy: 0.9930 - val_loss: 0.3690 - val_wine_quality_loss: 0.3396 - val_wine_type_loss: 0.0294 - val_wine_quality_root_mean_squared_error: 0.5828 - val_wine_type_accuracy: 0.9949
# Epoch 46/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3606 - wine_quality_loss: 0.3307 - wine_type_loss: 0.0299 - wine_quality_root_mean_squared_error: 0.5751 - wine_type_accuracy: 0.9933 - val_loss: 0.3739 - val_wine_quality_loss: 0.3447 - val_wine_type_loss: 0.0293 - val_wine_quality_root_mean_squared_error: 0.5871 - val_wine_type_accuracy: 0.9949
# Epoch 47/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3584 - wine_quality_loss: 0.3287 - wine_type_loss: 0.0297 - wine_quality_root_mean_squared_error: 0.5733 - wine_type_accuracy: 0.9933 - val_loss: 0.3660 - val_wine_quality_loss: 0.3369 - val_wine_type_loss: 0.0291 - val_wine_quality_root_mean_squared_error: 0.5804 - val_wine_type_accuracy: 0.9949
# Epoch 48/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3558 - wine_quality_loss: 0.3263 - wine_type_loss: 0.0295 - wine_quality_root_mean_squared_error: 0.5712 - wine_type_accuracy: 0.9933 - val_loss: 0.3635 - val_wine_quality_loss: 0.3345 - val_wine_type_loss: 0.0290 - val_wine_quality_root_mean_squared_error: 0.5784 - val_wine_type_accuracy: 0.9949
# Epoch 49/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3531 - wine_quality_loss: 0.3239 - wine_type_loss: 0.0292 - wine_quality_root_mean_squared_error: 0.5692 - wine_type_accuracy: 0.9937 - val_loss: 0.3577 - val_wine_quality_loss: 0.3288 - val_wine_type_loss: 0.0290 - val_wine_quality_root_mean_squared_error: 0.5734 - val_wine_type_accuracy: 0.9949
# Epoch 50/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3503 - wine_quality_loss: 0.3213 - wine_type_loss: 0.0290 - wine_quality_root_mean_squared_error: 0.5669 - wine_type_accuracy: 0.9937 - val_loss: 0.3609 - val_wine_quality_loss: 0.3321 - val_wine_type_loss: 0.0288 - val_wine_quality_root_mean_squared_error: 0.5763 - val_wine_type_accuracy: 0.9949
# Epoch 51/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3482 - wine_quality_loss: 0.3194 - wine_type_loss: 0.0288 - wine_quality_root_mean_squared_error: 0.5652 - wine_type_accuracy: 0.9933 - val_loss: 0.3537 - val_wine_quality_loss: 0.3249 - val_wine_type_loss: 0.0287 - val_wine_quality_root_mean_squared_error: 0.5700 - val_wine_type_accuracy: 0.9949
# Epoch 52/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3455 - wine_quality_loss: 0.3170 - wine_type_loss: 0.0285 - wine_quality_root_mean_squared_error: 0.5630 - wine_type_accuracy: 0.9940 - val_loss: 0.3556 - val_wine_quality_loss: 0.3269 - val_wine_type_loss: 0.0286 - val_wine_quality_root_mean_squared_error: 0.5718 - val_wine_type_accuracy: 0.9949
# Epoch 53/180
# 99/99 [==============================] - 1s 5ms/step - loss: 0.3438 - wine_quality_loss: 0.3154 - wine_type_loss: 0.0284 - wine_quality_root_mean_squared_error: 0.5616 - wine_type_accuracy: 0.9940 - val_loss: 0.3576 - val_wine_quality_loss: 0.3290 - val_wine_type_loss: 0.0285 - val_wine_quality_root_mean_squared_error: 0.5736 - val_wine_type_accuracy: 0.9949
# Epoch 54/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3433 - wine_quality_loss: 0.3152 - wine_type_loss: 0.0281 - wine_quality_root_mean_squared_error: 0.5614 - wine_type_accuracy: 0.9940 - val_loss: 0.3588 - val_wine_quality_loss: 0.3303 - val_wine_type_loss: 0.0285 - val_wine_quality_root_mean_squared_error: 0.5747 - val_wine_type_accuracy: 0.9949
# Epoch 55/180
# 99/99 [==============================] - 1s 5ms/step - loss: 0.3411 - wine_quality_loss: 0.3131 - wine_type_loss: 0.0279 - wine_quality_root_mean_squared_error: 0.5596 - wine_type_accuracy: 0.9943 - val_loss: 0.3494 - val_wine_quality_loss: 0.3210 - val_wine_type_loss: 0.0284 - val_wine_quality_root_mean_squared_error: 0.5666 - val_wine_type_accuracy: 0.9949
# Epoch 56/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3386 - wine_quality_loss: 0.3108 - wine_type_loss: 0.0277 - wine_quality_root_mean_squared_error: 0.5575 - wine_type_accuracy: 0.9943 - val_loss: 0.3503 - val_wine_quality_loss: 0.3219 - val_wine_type_loss: 0.0283 - val_wine_quality_root_mean_squared_error: 0.5674 - val_wine_type_accuracy: 0.9949
# Epoch 57/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3382 - wine_quality_loss: 0.3106 - wine_type_loss: 0.0276 - wine_quality_root_mean_squared_error: 0.5573 - wine_type_accuracy: 0.9946 - val_loss: 0.3525 - val_wine_quality_loss: 0.3242 - val_wine_type_loss: 0.0283 - val_wine_quality_root_mean_squared_error: 0.5694 - val_wine_type_accuracy: 0.9949
# Epoch 58/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3378 - wine_quality_loss: 0.3104 - wine_type_loss: 0.0274 - wine_quality_root_mean_squared_error: 0.5572 - wine_type_accuracy: 0.9946 - val_loss: 0.3486 - val_wine_quality_loss: 0.3205 - val_wine_type_loss: 0.0281 - val_wine_quality_root_mean_squared_error: 0.5661 - val_wine_type_accuracy: 0.9949
# Epoch 59/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3351 - wine_quality_loss: 0.3079 - wine_type_loss: 0.0272 - wine_quality_root_mean_squared_error: 0.5549 - wine_type_accuracy: 0.9943 - val_loss: 0.3523 - val_wine_quality_loss: 0.3243 - val_wine_type_loss: 0.0281 - val_wine_quality_root_mean_squared_error: 0.5694 - val_wine_type_accuracy: 0.9949
# Epoch 60/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3337 - wine_quality_loss: 0.3067 - wine_type_loss: 0.0270 - wine_quality_root_mean_squared_error: 0.5538 - wine_type_accuracy: 0.9943 - val_loss: 0.3548 - val_wine_quality_loss: 0.3268 - val_wine_type_loss: 0.0281 - val_wine_quality_root_mean_squared_error: 0.5716 - val_wine_type_accuracy: 0.9949
# Epoch 61/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3318 - wine_quality_loss: 0.3050 - wine_type_loss: 0.0269 - wine_quality_root_mean_squared_error: 0.5523 - wine_type_accuracy: 0.9943 - val_loss: 0.3540 - val_wine_quality_loss: 0.3260 - val_wine_type_loss: 0.0280 - val_wine_quality_root_mean_squared_error: 0.5709 - val_wine_type_accuracy: 0.9949
# Epoch 62/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3311 - wine_quality_loss: 0.3043 - wine_type_loss: 0.0267 - wine_quality_root_mean_squared_error: 0.5517 - wine_type_accuracy: 0.9946 - val_loss: 0.3569 - val_wine_quality_loss: 0.3289 - val_wine_type_loss: 0.0280 - val_wine_quality_root_mean_squared_error: 0.5735 - val_wine_type_accuracy: 0.9949
# Epoch 63/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3296 - wine_quality_loss: 0.3031 - wine_type_loss: 0.0265 - wine_quality_root_mean_squared_error: 0.5505 - wine_type_accuracy: 0.9946 - val_loss: 0.3451 - val_wine_quality_loss: 0.3172 - val_wine_type_loss: 0.0279 - val_wine_quality_root_mean_squared_error: 0.5632 - val_wine_type_accuracy: 0.9949
# Epoch 64/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3292 - wine_quality_loss: 0.3028 - wine_type_loss: 0.0264 - wine_quality_root_mean_squared_error: 0.5503 - wine_type_accuracy: 0.9946 - val_loss: 0.3441 - val_wine_quality_loss: 0.3163 - val_wine_type_loss: 0.0279 - val_wine_quality_root_mean_squared_error: 0.5624 - val_wine_type_accuracy: 0.9949
# Epoch 65/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3268 - wine_quality_loss: 0.3006 - wine_type_loss: 0.0262 - wine_quality_root_mean_squared_error: 0.5483 - wine_type_accuracy: 0.9949 - val_loss: 0.3518 - val_wine_quality_loss: 0.3242 - val_wine_type_loss: 0.0277 - val_wine_quality_root_mean_squared_error: 0.5693 - val_wine_type_accuracy: 0.9949
# Epoch 66/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3267 - wine_quality_loss: 0.3007 - wine_type_loss: 0.0260 - wine_quality_root_mean_squared_error: 0.5483 - wine_type_accuracy: 0.9949 - val_loss: 0.3422 - val_wine_quality_loss: 0.3146 - val_wine_type_loss: 0.0277 - val_wine_quality_root_mean_squared_error: 0.5609 - val_wine_type_accuracy: 0.9949
# Epoch 67/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3262 - wine_quality_loss: 0.3003 - wine_type_loss: 0.0259 - wine_quality_root_mean_squared_error: 0.5480 - wine_type_accuracy: 0.9946 - val_loss: 0.3431 - val_wine_quality_loss: 0.3154 - val_wine_type_loss: 0.0276 - val_wine_quality_root_mean_squared_error: 0.5616 - val_wine_type_accuracy: 0.9949
# Epoch 68/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3246 - wine_quality_loss: 0.2989 - wine_type_loss: 0.0258 - wine_quality_root_mean_squared_error: 0.5467 - wine_type_accuracy: 0.9949 - val_loss: 0.3439 - val_wine_quality_loss: 0.3163 - val_wine_type_loss: 0.0276 - val_wine_quality_root_mean_squared_error: 0.5624 - val_wine_type_accuracy: 0.9949
# Epoch 69/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3233 - wine_quality_loss: 0.2976 - wine_type_loss: 0.0256 - wine_quality_root_mean_squared_error: 0.5456 - wine_type_accuracy: 0.9949 - val_loss: 0.3435 - val_wine_quality_loss: 0.3159 - val_wine_type_loss: 0.0275 - val_wine_quality_root_mean_squared_error: 0.5621 - val_wine_type_accuracy: 0.9949
# Epoch 70/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3235 - wine_quality_loss: 0.2980 - wine_type_loss: 0.0254 - wine_quality_root_mean_squared_error: 0.5459 - wine_type_accuracy: 0.9949 - val_loss: 0.3429 - val_wine_quality_loss: 0.3155 - val_wine_type_loss: 0.0274 - val_wine_quality_root_mean_squared_error: 0.5617 - val_wine_type_accuracy: 0.9949
# Epoch 71/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3223 - wine_quality_loss: 0.2970 - wine_type_loss: 0.0253 - wine_quality_root_mean_squared_error: 0.5450 - wine_type_accuracy: 0.9956 - val_loss: 0.3431 - val_wine_quality_loss: 0.3157 - val_wine_type_loss: 0.0274 - val_wine_quality_root_mean_squared_error: 0.5619 - val_wine_type_accuracy: 0.9949
# Epoch 72/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3204 - wine_quality_loss: 0.2953 - wine_type_loss: 0.0252 - wine_quality_root_mean_squared_error: 0.5434 - wine_type_accuracy: 0.9956 - val_loss: 0.3520 - val_wine_quality_loss: 0.3246 - val_wine_type_loss: 0.0273 - val_wine_quality_root_mean_squared_error: 0.5698 - val_wine_type_accuracy: 0.9949
# Epoch 73/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3208 - wine_quality_loss: 0.2957 - wine_type_loss: 0.0250 - wine_quality_root_mean_squared_error: 0.5438 - wine_type_accuracy: 0.9952 - val_loss: 0.3425 - val_wine_quality_loss: 0.3152 - val_wine_type_loss: 0.0273 - val_wine_quality_root_mean_squared_error: 0.5614 - val_wine_type_accuracy: 0.9949
# Epoch 74/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3199 - wine_quality_loss: 0.2950 - wine_type_loss: 0.0249 - wine_quality_root_mean_squared_error: 0.5431 - wine_type_accuracy: 0.9956 - val_loss: 0.3438 - val_wine_quality_loss: 0.3165 - val_wine_type_loss: 0.0272 - val_wine_quality_root_mean_squared_error: 0.5626 - val_wine_type_accuracy: 0.9949
# Epoch 75/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3174 - wine_quality_loss: 0.2926 - wine_type_loss: 0.0247 - wine_quality_root_mean_squared_error: 0.5410 - wine_type_accuracy: 0.9952 - val_loss: 0.3511 - val_wine_quality_loss: 0.3240 - val_wine_type_loss: 0.0271 - val_wine_quality_root_mean_squared_error: 0.5692 - val_wine_type_accuracy: 0.9949
# Epoch 76/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3175 - wine_quality_loss: 0.2929 - wine_type_loss: 0.0246 - wine_quality_root_mean_squared_error: 0.5412 - wine_type_accuracy: 0.9956 - val_loss: 0.3506 - val_wine_quality_loss: 0.3235 - val_wine_type_loss: 0.0271 - val_wine_quality_root_mean_squared_error: 0.5688 - val_wine_type_accuracy: 0.9949
# Epoch 77/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3172 - wine_quality_loss: 0.2927 - wine_type_loss: 0.0245 - wine_quality_root_mean_squared_error: 0.5410 - wine_type_accuracy: 0.9956 - val_loss: 0.3411 - val_wine_quality_loss: 0.3141 - val_wine_type_loss: 0.0270 - val_wine_quality_root_mean_squared_error: 0.5604 - val_wine_type_accuracy: 0.9949
# Epoch 78/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3162 - wine_quality_loss: 0.2919 - wine_type_loss: 0.0244 - wine_quality_root_mean_squared_error: 0.5403 - wine_type_accuracy: 0.9956 - val_loss: 0.3400 - val_wine_quality_loss: 0.3130 - val_wine_type_loss: 0.0270 - val_wine_quality_root_mean_squared_error: 0.5594 - val_wine_type_accuracy: 0.9949
# Epoch 79/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3160 - wine_quality_loss: 0.2918 - wine_type_loss: 0.0242 - wine_quality_root_mean_squared_error: 0.5402 - wine_type_accuracy: 0.9956 - val_loss: 0.3383 - val_wine_quality_loss: 0.3114 - val_wine_type_loss: 0.0269 - val_wine_quality_root_mean_squared_error: 0.5580 - val_wine_type_accuracy: 0.9949
# Epoch 80/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3136 - wine_quality_loss: 0.2895 - wine_type_loss: 0.0241 - wine_quality_root_mean_squared_error: 0.5381 - wine_type_accuracy: 0.9956 - val_loss: 0.3436 - val_wine_quality_loss: 0.3168 - val_wine_type_loss: 0.0269 - val_wine_quality_root_mean_squared_error: 0.5628 - val_wine_type_accuracy: 0.9949
# Epoch 81/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3139 - wine_quality_loss: 0.2899 - wine_type_loss: 0.0240 - wine_quality_root_mean_squared_error: 0.5384 - wine_type_accuracy: 0.9956 - val_loss: 0.3382 - val_wine_quality_loss: 0.3114 - val_wine_type_loss: 0.0268 - val_wine_quality_root_mean_squared_error: 0.5580 - val_wine_type_accuracy: 0.9949
# Epoch 82/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3136 - wine_quality_loss: 0.2897 - wine_type_loss: 0.0239 - wine_quality_root_mean_squared_error: 0.5382 - wine_type_accuracy: 0.9959 - val_loss: 0.3365 - val_wine_quality_loss: 0.3098 - val_wine_type_loss: 0.0267 - val_wine_quality_root_mean_squared_error: 0.5566 - val_wine_type_accuracy: 0.9949
# Epoch 83/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3135 - wine_quality_loss: 0.2898 - wine_type_loss: 0.0238 - wine_quality_root_mean_squared_error: 0.5383 - wine_type_accuracy: 0.9959 - val_loss: 0.3382 - val_wine_quality_loss: 0.3116 - val_wine_type_loss: 0.0266 - val_wine_quality_root_mean_squared_error: 0.5582 - val_wine_type_accuracy: 0.9949
# Epoch 84/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3117 - wine_quality_loss: 0.2880 - wine_type_loss: 0.0237 - wine_quality_root_mean_squared_error: 0.5367 - wine_type_accuracy: 0.9952 - val_loss: 0.3405 - val_wine_quality_loss: 0.3139 - val_wine_type_loss: 0.0266 - val_wine_quality_root_mean_squared_error: 0.5602 - val_wine_type_accuracy: 0.9949
# Epoch 85/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3110 - wine_quality_loss: 0.2875 - wine_type_loss: 0.0235 - wine_quality_root_mean_squared_error: 0.5362 - wine_type_accuracy: 0.9959 - val_loss: 0.3417 - val_wine_quality_loss: 0.3152 - val_wine_type_loss: 0.0266 - val_wine_quality_root_mean_squared_error: 0.5614 - val_wine_type_accuracy: 0.9949
# Epoch 86/180
# 99/99 [==============================] - 1s 6ms/step - loss: 0.3095 - wine_quality_loss: 0.2861 - wine_type_loss: 0.0234 - wine_quality_root_mean_squared_error: 0.5349 - wine_type_accuracy: 0.9959 - val_loss: 0.3462 - val_wine_quality_loss: 0.3197 - val_wine_type_loss: 0.0265 - val_wine_quality_root_mean_squared_error: 0.5654 - val_wine_type_accuracy: 0.9949
# Epoch 87/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3101 - wine_quality_loss: 0.2868 - wine_type_loss: 0.0233 - wine_quality_root_mean_squared_error: 0.5355 - wine_type_accuracy: 0.9959 - val_loss: 0.3432 - val_wine_quality_loss: 0.3169 - val_wine_type_loss: 0.0263 - val_wine_quality_root_mean_squared_error: 0.5629 - val_wine_type_accuracy: 0.9949
# Epoch 88/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3096 - wine_quality_loss: 0.2864 - wine_type_loss: 0.0232 - wine_quality_root_mean_squared_error: 0.5352 - wine_type_accuracy: 0.9959 - val_loss: 0.3368 - val_wine_quality_loss: 0.3106 - val_wine_type_loss: 0.0263 - val_wine_quality_root_mean_squared_error: 0.5573 - val_wine_type_accuracy: 0.9949
# Epoch 89/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3090 - wine_quality_loss: 0.2860 - wine_type_loss: 0.0230 - wine_quality_root_mean_squared_error: 0.5348 - wine_type_accuracy: 0.9959 - val_loss: 0.3385 - val_wine_quality_loss: 0.3122 - val_wine_type_loss: 0.0263 - val_wine_quality_root_mean_squared_error: 0.5588 - val_wine_type_accuracy: 0.9949
# Epoch 90/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3092 - wine_quality_loss: 0.2862 - wine_type_loss: 0.0229 - wine_quality_root_mean_squared_error: 0.5350 - wine_type_accuracy: 0.9962 - val_loss: 0.3371 - val_wine_quality_loss: 0.3109 - val_wine_type_loss: 0.0262 - val_wine_quality_root_mean_squared_error: 0.5576 - val_wine_type_accuracy: 0.9949
# Epoch 91/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3085 - wine_quality_loss: 0.2857 - wine_type_loss: 0.0228 - wine_quality_root_mean_squared_error: 0.5345 - wine_type_accuracy: 0.9959 - val_loss: 0.3351 - val_wine_quality_loss: 0.3090 - val_wine_type_loss: 0.0261 - val_wine_quality_root_mean_squared_error: 0.5559 - val_wine_type_accuracy: 0.9949
# Epoch 92/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3069 - wine_quality_loss: 0.2842 - wine_type_loss: 0.0227 - wine_quality_root_mean_squared_error: 0.5331 - wine_type_accuracy: 0.9959 - val_loss: 0.3408 - val_wine_quality_loss: 0.3148 - val_wine_type_loss: 0.0260 - val_wine_quality_root_mean_squared_error: 0.5611 - val_wine_type_accuracy: 0.9949
# Epoch 93/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3066 - wine_quality_loss: 0.2840 - wine_type_loss: 0.0227 - wine_quality_root_mean_squared_error: 0.5329 - wine_type_accuracy: 0.9959 - val_loss: 0.3383 - val_wine_quality_loss: 0.3123 - val_wine_type_loss: 0.0259 - val_wine_quality_root_mean_squared_error: 0.5589 - val_wine_type_accuracy: 0.9949
# Epoch 94/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3060 - wine_quality_loss: 0.2834 - wine_type_loss: 0.0225 - wine_quality_root_mean_squared_error: 0.5324 - wine_type_accuracy: 0.9959 - val_loss: 0.3374 - val_wine_quality_loss: 0.3115 - val_wine_type_loss: 0.0259 - val_wine_quality_root_mean_squared_error: 0.5581 - val_wine_type_accuracy: 0.9949
# Epoch 95/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3043 - wine_quality_loss: 0.2819 - wine_type_loss: 0.0224 - wine_quality_root_mean_squared_error: 0.5310 - wine_type_accuracy: 0.9962 - val_loss: 0.3399 - val_wine_quality_loss: 0.3139 - val_wine_type_loss: 0.0260 - val_wine_quality_root_mean_squared_error: 0.5603 - val_wine_type_accuracy: 0.9949
# Epoch 96/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3049 - wine_quality_loss: 0.2825 - wine_type_loss: 0.0223 - wine_quality_root_mean_squared_error: 0.5315 - wine_type_accuracy: 0.9959 - val_loss: 0.3373 - val_wine_quality_loss: 0.3114 - val_wine_type_loss: 0.0258 - val_wine_quality_root_mean_squared_error: 0.5581 - val_wine_type_accuracy: 0.9949
# Epoch 97/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3040 - wine_quality_loss: 0.2818 - wine_type_loss: 0.0222 - wine_quality_root_mean_squared_error: 0.5309 - wine_type_accuracy: 0.9959 - val_loss: 0.3408 - val_wine_quality_loss: 0.3150 - val_wine_type_loss: 0.0258 - val_wine_quality_root_mean_squared_error: 0.5613 - val_wine_type_accuracy: 0.9949
# Epoch 98/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3032 - wine_quality_loss: 0.2811 - wine_type_loss: 0.0221 - wine_quality_root_mean_squared_error: 0.5302 - wine_type_accuracy: 0.9959 - val_loss: 0.3339 - val_wine_quality_loss: 0.3082 - val_wine_type_loss: 0.0257 - val_wine_quality_root_mean_squared_error: 0.5552 - val_wine_type_accuracy: 0.9949
# Epoch 99/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3019 - wine_quality_loss: 0.2799 - wine_type_loss: 0.0220 - wine_quality_root_mean_squared_error: 0.5291 - wine_type_accuracy: 0.9962 - val_loss: 0.3345 - val_wine_quality_loss: 0.3088 - val_wine_type_loss: 0.0257 - val_wine_quality_root_mean_squared_error: 0.5557 - val_wine_type_accuracy: 0.9949
# Epoch 100/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3020 - wine_quality_loss: 0.2801 - wine_type_loss: 0.0219 - wine_quality_root_mean_squared_error: 0.5293 - wine_type_accuracy: 0.9959 - val_loss: 0.3350 - val_wine_quality_loss: 0.3094 - val_wine_type_loss: 0.0256 - val_wine_quality_root_mean_squared_error: 0.5562 - val_wine_type_accuracy: 0.9949
# Epoch 101/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3023 - wine_quality_loss: 0.2805 - wine_type_loss: 0.0218 - wine_quality_root_mean_squared_error: 0.5296 - wine_type_accuracy: 0.9962 - val_loss: 0.3423 - val_wine_quality_loss: 0.3166 - val_wine_type_loss: 0.0257 - val_wine_quality_root_mean_squared_error: 0.5626 - val_wine_type_accuracy: 0.9949
# Epoch 102/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3000 - wine_quality_loss: 0.2783 - wine_type_loss: 0.0217 - wine_quality_root_mean_squared_error: 0.5276 - wine_type_accuracy: 0.9959 - val_loss: 0.3375 - val_wine_quality_loss: 0.3118 - val_wine_type_loss: 0.0257 - val_wine_quality_root_mean_squared_error: 0.5584 - val_wine_type_accuracy: 0.9949
# Epoch 103/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3014 - wine_quality_loss: 0.2798 - wine_type_loss: 0.0216 - wine_quality_root_mean_squared_error: 0.5289 - wine_type_accuracy: 0.9959 - val_loss: 0.3338 - val_wine_quality_loss: 0.3083 - val_wine_type_loss: 0.0255 - val_wine_quality_root_mean_squared_error: 0.5552 - val_wine_type_accuracy: 0.9949
# Epoch 104/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2992 - wine_quality_loss: 0.2777 - wine_type_loss: 0.0215 - wine_quality_root_mean_squared_error: 0.5270 - wine_type_accuracy: 0.9959 - val_loss: 0.3395 - val_wine_quality_loss: 0.3141 - val_wine_type_loss: 0.0254 - val_wine_quality_root_mean_squared_error: 0.5604 - val_wine_type_accuracy: 0.9949
# Epoch 105/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3000 - wine_quality_loss: 0.2786 - wine_type_loss: 0.0214 - wine_quality_root_mean_squared_error: 0.5278 - wine_type_accuracy: 0.9959 - val_loss: 0.3340 - val_wine_quality_loss: 0.3086 - val_wine_type_loss: 0.0254 - val_wine_quality_root_mean_squared_error: 0.5555 - val_wine_type_accuracy: 0.9949
# Epoch 106/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.2998 - wine_quality_loss: 0.2785 - wine_type_loss: 0.0213 - wine_quality_root_mean_squared_error: 0.5277 - wine_type_accuracy: 0.9962 - val_loss: 0.3362 - val_wine_quality_loss: 0.3109 - val_wine_type_loss: 0.0254 - val_wine_quality_root_mean_squared_error: 0.5576 - val_wine_type_accuracy: 0.9949
# Epoch 107/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.2985 - wine_quality_loss: 0.2773 - wine_type_loss: 0.0212 - wine_quality_root_mean_squared_error: 0.5266 - wine_type_accuracy: 0.9959 - val_loss: 0.3368 - val_wine_quality_loss: 0.3114 - val_wine_type_loss: 0.0254 - val_wine_quality_root_mean_squared_error: 0.5580 - val_wine_type_accuracy: 0.9949
# Epoch 108/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.2986 - wine_quality_loss: 0.2775 - wine_type_loss: 0.0211 - wine_quality_root_mean_squared_error: 0.5268 - wine_type_accuracy: 0.9962 - val_loss: 0.3449 - val_wine_quality_loss: 0.3195 - val_wine_type_loss: 0.0254 - val_wine_quality_root_mean_squared_error: 0.5653 - val_wine_type_accuracy: 0.9949
# Epoch 109/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.2967 - wine_quality_loss: 0.2757 - wine_type_loss: 0.0210 - wine_quality_root_mean_squared_error: 0.5251 - wine_type_accuracy: 0.9962 - val_loss: 0.3376 - val_wine_quality_loss: 0.3123 - val_wine_type_loss: 0.0253 - val_wine_quality_root_mean_squared_error: 0.5588 - val_wine_type_accuracy: 0.9949
# Epoch 110/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.2959 - wine_quality_loss: 0.2750 - wine_type_loss: 0.0209 - wine_quality_root_mean_squared_error: 0.5244 - wine_type_accuracy: 0.9959 - val_loss: 0.3318 - val_wine_quality_loss: 0.3065 - val_wine_type_loss: 0.0253 - val_wine_quality_root_mean_squared_error: 0.5536 - val_wine_type_accuracy: 0.9949
# Epoch 111/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.2970 - wine_quality_loss: 0.2761 - wine_type_loss: 0.0208 - wine_quality_root_mean_squared_error: 0.5255 - wine_type_accuracy: 0.9959 - val_loss: 0.3440 - val_wine_quality_loss: 0.3188 - val_wine_type_loss: 0.0252 - val_wine_quality_root_mean_squared_error: 0.5647 - val_wine_type_accuracy: 0.9949
# Epoch 112/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.2965 - wine_quality_loss: 0.2758 - wine_type_loss: 0.0207 - wine_quality_root_mean_squared_error: 0.5252 - wine_type_accuracy: 0.9962 - val_loss: 0.3302 - val_wine_quality_loss: 0.3050 - val_wine_type_loss: 0.0252 - val_wine_quality_root_mean_squared_error: 0.5523 - val_wine_type_accuracy: 0.9949
# Epoch 113/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2950 - wine_quality_loss: 0.2743 - wine_type_loss: 0.0206 - wine_quality_root_mean_squared_error: 0.5238 - wine_type_accuracy: 0.9959 - val_loss: 0.3349 - val_wine_quality_loss: 0.3097 - val_wine_type_loss: 0.0251 - val_wine_quality_root_mean_squared_error: 0.5565 - val_wine_type_accuracy: 0.9949
# Epoch 114/180
# 99/99 [==============================] - 0s 5ms/step - loss: 0.2948 - wine_quality_loss: 0.2743 - wine_type_loss: 0.0205 - wine_quality_root_mean_squared_error: 0.5237 - wine_type_accuracy: 0.9962 - val_loss: 0.3347 - val_wine_quality_loss: 0.3096 - val_wine_type_loss: 0.0250 - val_wine_quality_root_mean_squared_error: 0.5565 - val_wine_type_accuracy: 0.9949
# Epoch 115/180
# 99/99 [==============================] - 1s 8ms/step - loss: 0.2947 - wine_quality_loss: 0.2742 - wine_type_loss: 0.0205 - wine_quality_root_mean_squared_error: 0.5237 - wine_type_accuracy: 0.9965 - val_loss: 0.3473 - val_wine_quality_loss: 0.3222 - val_wine_type_loss: 0.0251 - val_wine_quality_root_mean_squared_error: 0.5676 - val_wine_type_accuracy: 0.9949
# Epoch 116/180
# 99/99 [==============================] - 1s 6ms/step - loss: 0.2931 - wine_quality_loss: 0.2727 - wine_type_loss: 0.0204 - wine_quality_root_mean_squared_error: 0.5223 - wine_type_accuracy: 0.9962 - val_loss: 0.3371 - val_wine_quality_loss: 0.3120 - val_wine_type_loss: 0.0250 - val_wine_quality_root_mean_squared_error: 0.5586 - val_wine_type_accuracy: 0.9949
# Epoch 117/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2933 - wine_quality_loss: 0.2731 - wine_type_loss: 0.0203 - wine_quality_root_mean_squared_error: 0.5226 - wine_type_accuracy: 0.9965 - val_loss: 0.3353 - val_wine_quality_loss: 0.3103 - val_wine_type_loss: 0.0250 - val_wine_quality_root_mean_squared_error: 0.5570 - val_wine_type_accuracy: 0.9949
# Epoch 118/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2924 - wine_quality_loss: 0.2722 - wine_type_loss: 0.0202 - wine_quality_root_mean_squared_error: 0.5217 - wine_type_accuracy: 0.9965 - val_loss: 0.3381 - val_wine_quality_loss: 0.3129 - val_wine_type_loss: 0.0252 - val_wine_quality_root_mean_squared_error: 0.5593 - val_wine_type_accuracy: 0.9949
# Epoch 119/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2930 - wine_quality_loss: 0.2728 - wine_type_loss: 0.0201 - wine_quality_root_mean_squared_error: 0.5223 - wine_type_accuracy: 0.9965 - val_loss: 0.3333 - val_wine_quality_loss: 0.3082 - val_wine_type_loss: 0.0251 - val_wine_quality_root_mean_squared_error: 0.5551 - val_wine_type_accuracy: 0.9949
# Epoch 120/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.2923 - wine_quality_loss: 0.2722 - wine_type_loss: 0.0201 - wine_quality_root_mean_squared_error: 0.5217 - wine_type_accuracy: 0.9965 - val_loss: 0.3530 - val_wine_quality_loss: 0.3278 - val_wine_type_loss: 0.0252 - val_wine_quality_root_mean_squared_error: 0.5725 - val_wine_type_accuracy: 0.9949
# Epoch 121/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2903 - wine_quality_loss: 0.2703 - wine_type_loss: 0.0200 - wine_quality_root_mean_squared_error: 0.5199 - wine_type_accuracy: 0.9965 - val_loss: 0.3521 - val_wine_quality_loss: 0.3270 - val_wine_type_loss: 0.0251 - val_wine_quality_root_mean_squared_error: 0.5718 - val_wine_type_accuracy: 0.9949
# Epoch 122/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2910 - wine_quality_loss: 0.2711 - wine_type_loss: 0.0199 - wine_quality_root_mean_squared_error: 0.5206 - wine_type_accuracy: 0.9965 - val_loss: 0.3341 - val_wine_quality_loss: 0.3091 - val_wine_type_loss: 0.0250 - val_wine_quality_root_mean_squared_error: 0.5559 - val_wine_type_accuracy: 0.9949
# Epoch 123/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2914 - wine_quality_loss: 0.2715 - wine_type_loss: 0.0198 - wine_quality_root_mean_squared_error: 0.5211 - wine_type_accuracy: 0.9965 - val_loss: 0.3350 - val_wine_quality_loss: 0.3100 - val_wine_type_loss: 0.0249 - val_wine_quality_root_mean_squared_error: 0.5568 - val_wine_type_accuracy: 0.9949
# Epoch 124/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2894 - wine_quality_loss: 0.2697 - wine_type_loss: 0.0197 - wine_quality_root_mean_squared_error: 0.5193 - wine_type_accuracy: 0.9962 - val_loss: 0.3339 - val_wine_quality_loss: 0.3090 - val_wine_type_loss: 0.0249 - val_wine_quality_root_mean_squared_error: 0.5559 - val_wine_type_accuracy: 0.9949
# Epoch 125/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2896 - wine_quality_loss: 0.2700 - wine_type_loss: 0.0196 - wine_quality_root_mean_squared_error: 0.5196 - wine_type_accuracy: 0.9962 - val_loss: 0.3353 - val_wine_quality_loss: 0.3104 - val_wine_type_loss: 0.0248 - val_wine_quality_root_mean_squared_error: 0.5571 - val_wine_type_accuracy: 0.9949
# Epoch 126/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2863 - wine_quality_loss: 0.2667 - wine_type_loss: 0.0196 - wine_quality_root_mean_squared_error: 0.5165 - wine_type_accuracy: 0.9965 - val_loss: 0.3437 - val_wine_quality_loss: 0.3187 - val_wine_type_loss: 0.0250 - val_wine_quality_root_mean_squared_error: 0.5646 - val_wine_type_accuracy: 0.9949
# Epoch 127/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2888 - wine_quality_loss: 0.2693 - wine_type_loss: 0.0195 - wine_quality_root_mean_squared_error: 0.5190 - wine_type_accuracy: 0.9965 - val_loss: 0.3320 - val_wine_quality_loss: 0.3071 - val_wine_type_loss: 0.0249 - val_wine_quality_root_mean_squared_error: 0.5541 - val_wine_type_accuracy: 0.9949
# Epoch 128/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2877 - wine_quality_loss: 0.2682 - wine_type_loss: 0.0195 - wine_quality_root_mean_squared_error: 0.5179 - wine_type_accuracy: 0.9962 - val_loss: 0.3380 - val_wine_quality_loss: 0.3131 - val_wine_type_loss: 0.0249 - val_wine_quality_root_mean_squared_error: 0.5596 - val_wine_type_accuracy: 0.9949
# Epoch 129/180
# ...
# Epoch 139/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.2830 - wine_quality_loss: 0.2642 - wine_type_loss: 0.0187 - wine_quality_root_mean_squared_error: 0.5140 - wine_type_accuracy: 0.9962 - val_loss: 0.3353 - val_wine_quality_loss: 0.3107 - val_wine_type_loss: 0.0246 - val_wine_quality_root_mean_squared_error: 0.5574 - val_wine_type_accuracy: 0.9949
# Epoch 140/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.2825 - wine_quality_loss: 0.2639 - wine_type_loss: 0.0186 - wine_quality_root_mean_squared_error: 0.5137 - wine_type_accuracy: 0.9965 - val_loss: 0.3365 - val_wine_quality_loss: 0.3120 - val_wine_type_loss: 0.0246 - val_wine_quality_root_mean_squared_error: 0.5585 - val_wine_type_accuracy: 0.9949
# Epoch 141/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.2821 - wine_quality_loss: 0.2636 - wine_type_loss: 0.0185 - wine_quality_root_mean_squared_error: 0.5134 - wine_type_accuracy: 0.9965 - val_loss: 0.3331 - val_wine_quality_loss: 0.3085 - val_wine_type_loss: 0.0246 - val_wine_quality_root_mean_squared_error: 0.5554 - val_wine_type_accuracy: 0.9949
# Epoch 142/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2835 - wine_quality_loss: 0.2650 - wine_type_loss: 0.0185 - wine_quality_root_mean_squared_error: 0.5148 - wine_type_accuracy: 0.9965 - val_loss: 0.3320 - val_wine_quality_loss: 0.3074 - val_wine_type_loss: 0.0246 - val_wine_quality_root_mean_squared_error: 0.5544 - val_wine_type_accuracy: 0.9949
# Epoch 143/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2811 - wine_quality_loss: 0.2627 - wine_type_loss: 0.0184 - wine_quality_root_mean_squared_error: 0.5125 - wine_type_accuracy: 0.9965 - val_loss: 0.3336 - val_wine_quality_loss: 0.3090 - val_wine_type_loss: 0.0246 - val_wine_quality_root_mean_squared_error: 0.5559 - val_wine_type_accuracy: 0.9949
# Epoch 144/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2812 - wine_quality_loss: 0.2628 - wine_type_loss: 0.0184 - wine_quality_root_mean_squared_error: 0.5127 - wine_type_accuracy: 0.9965 - val_loss: 0.3407 - val_wine_quality_loss: 0.3162 - val_wine_type_loss: 0.0246 - val_wine_quality_root_mean_squared_error: 0.5623 - val_wine_type_accuracy: 0.9949
# Epoch 145/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2814 - wine_quality_loss: 0.2631 - wine_type_loss: 0.0183 - wine_quality_root_mean_squared_error: 0.5130 - wine_type_accuracy: 0.9965 - val_loss: 0.3312 - val_wine_quality_loss: 0.3066 - val_wine_type_loss: 0.0246 - val_wine_quality_root_mean_squared_error: 0.5537 - val_wine_type_accuracy: 0.9949
# Epoch 146/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2813 - wine_quality_loss: 0.2630 - wine_type_loss: 0.0183 - wine_quality_root_mean_squared_error: 0.5129 - wine_type_accuracy: 0.9965 - val_loss: 0.3313 - val_wine_quality_loss: 0.3068 - val_wine_type_loss: 0.0245 - val_wine_quality_root_mean_squared_error: 0.5539 - val_wine_type_accuracy: 0.9949
# Epoch 147/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.2802 - wine_quality_loss: 0.2620 - wine_type_loss: 0.0182 - wine_quality_root_mean_squared_error: 0.5118 - wine_type_accuracy: 0.9965 - val_loss: 0.3418 - val_wine_quality_loss: 0.3172 - val_wine_type_loss: 0.0246 - val_wine_quality_root_mean_squared_error: 0.5632 - val_wine_type_accuracy: 0.9949
# Epoch 148/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2803 - wine_quality_loss: 0.2622 - wine_type_loss: 0.0181 - wine_quality_root_mean_squared_error: 0.5120 - wine_type_accuracy: 0.9965 - val_loss: 0.3294 - val_wine_quality_loss: 0.3049 - val_wine_type_loss: 0.0245 - val_wine_quality_root_mean_squared_error: 0.5522 - val_wine_type_accuracy: 0.9949
# Epoch 149/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2796 - wine_quality_loss: 0.2615 - wine_type_loss: 0.0181 - wine_quality_root_mean_squared_error: 0.5114 - wine_type_accuracy: 0.9965 - val_loss: 0.3338 - val_wine_quality_loss: 0.3094 - val_wine_type_loss: 0.0245 - val_wine_quality_root_mean_squared_error: 0.5562 - val_wine_type_accuracy: 0.9949
# Epoch 150/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.2800 - wine_quality_loss: 0.2620 - wine_type_loss: 0.0180 - wine_quality_root_mean_squared_error: 0.5118 - wine_type_accuracy: 0.9965 - val_loss: 0.3348 - val_wine_quality_loss: 0.3104 - val_wine_type_loss: 0.0244 - val_wine_quality_root_mean_squared_error: 0.5571 - val_wine_type_accuracy: 0.9949
# Epoch 151/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2780 - wine_quality_loss: 0.2601 - wine_type_loss: 0.0179 - wine_quality_root_mean_squared_error: 0.5100 - wine_type_accuracy: 0.9965 - val_loss: 0.3403 - val_wine_quality_loss: 0.3159 - val_wine_type_loss: 0.0244 - val_wine_quality_root_mean_squared_error: 0.5620 - val_wine_type_accuracy: 0.9949
# Epoch 152/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.2789 - wine_quality_loss: 0.2610 - wine_type_loss: 0.0179 - wine_quality_root_mean_squared_error: 0.5109 - wine_type_accuracy: 0.9965 - val_loss: 0.3396 - val_wine_quality_loss: 0.3151 - val_wine_type_loss: 0.0244 - val_wine_quality_root_mean_squared_error: 0.5614 - val_wine_type_accuracy: 0.9949
# Epoch 153/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2785 - wine_quality_loss: 0.2607 - wine_type_loss: 0.0178 - wine_quality_root_mean_squared_error: 0.5106 - wine_type_accuracy: 0.9965 - val_loss: 0.3375 - val_wine_quality_loss: 0.3131 - val_wine_type_loss: 0.0244 - val_wine_quality_root_mean_squared_error: 0.5596 - val_wine_type_accuracy: 0.9949
# Epoch 154/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2775 - wine_quality_loss: 0.2598 - wine_type_loss: 0.0177 - wine_quality_root_mean_squared_error: 0.5097 - wine_type_accuracy: 0.9965 - val_loss: 0.3439 - val_wine_quality_loss: 0.3196 - val_wine_type_loss: 0.0244 - val_wine_quality_root_mean_squared_error: 0.5653 - val_wine_type_accuracy: 0.9949
# Epoch 155/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2782 - wine_quality_loss: 0.2605 - wine_type_loss: 0.0177 - wine_quality_root_mean_squared_error: 0.5104 - wine_type_accuracy: 0.9965 - val_loss: 0.3327 - val_wine_quality_loss: 0.3083 - val_wine_type_loss: 0.0243 - val_wine_quality_root_mean_squared_error: 0.5553 - val_wine_type_accuracy: 0.9949
# Epoch 156/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2772 - wine_quality_loss: 0.2596 - wine_type_loss: 0.0176 - wine_quality_root_mean_squared_error: 0.5095 - wine_type_accuracy: 0.9965 - val_loss: 0.3294 - val_wine_quality_loss: 0.3050 - val_wine_type_loss: 0.0244 - val_wine_quality_root_mean_squared_error: 0.5523 - val_wine_type_accuracy: 0.9949
# Epoch 157/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2774 - wine_quality_loss: 0.2598 - wine_type_loss: 0.0176 - wine_quality_root_mean_squared_error: 0.5097 - wine_type_accuracy: 0.9965 - val_loss: 0.3301 - val_wine_quality_loss: 0.3057 - val_wine_type_loss: 0.0244 - val_wine_quality_root_mean_squared_error: 0.5529 - val_wine_type_accuracy: 0.9949
# Epoch 158/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2761 - wine_quality_loss: 0.2585 - wine_type_loss: 0.0175 - wine_quality_root_mean_squared_error: 0.5085 - wine_type_accuracy: 0.9965 - val_loss: 0.3315 - val_wine_quality_loss: 0.3072 - val_wine_type_loss: 0.0243 - val_wine_quality_root_mean_squared_error: 0.5542 - val_wine_type_accuracy: 0.9949
# Epoch 159/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2753 - wine_quality_loss: 0.2578 - wine_type_loss: 0.0174 - wine_quality_root_mean_squared_error: 0.5078 - wine_type_accuracy: 0.9965 - val_loss: 0.3370 - val_wine_quality_loss: 0.3127 - val_wine_type_loss: 0.0243 - val_wine_quality_root_mean_squared_error: 0.5592 - val_wine_type_accuracy: 0.9949
# Epoch 160/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2758 - wine_quality_loss: 0.2584 - wine_type_loss: 0.0174 - wine_quality_root_mean_squared_error: 0.5083 - wine_type_accuracy: 0.9965 - val_loss: 0.3342 - val_wine_quality_loss: 0.3100 - val_wine_type_loss: 0.0242 - val_wine_quality_root_mean_squared_error: 0.5568 - val_wine_type_accuracy: 0.9949
# Epoch 161/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2758 - wine_quality_loss: 0.2585 - wine_type_loss: 0.0173 - wine_quality_root_mean_squared_error: 0.5084 - wine_type_accuracy: 0.9965 - val_loss: 0.3362 - val_wine_quality_loss: 0.3120 - val_wine_type_loss: 0.0243 - val_wine_quality_root_mean_squared_error: 0.5585 - val_wine_type_accuracy: 0.9949
# Epoch 162/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2746 - wine_quality_loss: 0.2573 - wine_type_loss: 0.0173 - wine_quality_root_mean_squared_error: 0.5072 - wine_type_accuracy: 0.9965 - val_loss: 0.3384 - val_wine_quality_loss: 0.3141 - val_wine_type_loss: 0.0242 - val_wine_quality_root_mean_squared_error: 0.5605 - val_wine_type_accuracy: 0.9949
# Epoch 163/180
# 99/99 [==============================] - 1s 6ms/step - loss: 0.2754 - wine_quality_loss: 0.2583 - wine_type_loss: 0.0172 - wine_quality_root_mean_squared_error: 0.5082 - wine_type_accuracy: 0.9965 - val_loss: 0.3385 - val_wine_quality_loss: 0.3143 - val_wine_type_loss: 0.0242 - val_wine_quality_root_mean_squared_error: 0.5606 - val_wine_type_accuracy: 0.9949
# Epoch 164/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2740 - wine_quality_loss: 0.2569 - wine_type_loss: 0.0171 - wine_quality_root_mean_squared_error: 0.5068 - wine_type_accuracy: 0.9965 - val_loss: 0.3350 - val_wine_quality_loss: 0.3107 - val_wine_type_loss: 0.0242 - val_wine_quality_root_mean_squared_error: 0.5574 - val_wine_type_accuracy: 0.9949
# Epoch 165/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2739 - wine_quality_loss: 0.2568 - wine_type_loss: 0.0171 - wine_quality_root_mean_squared_error: 0.5068 - wine_type_accuracy: 0.9965 - val_loss: 0.3464 - val_wine_quality_loss: 0.3221 - val_wine_type_loss: 0.0243 - val_wine_quality_root_mean_squared_error: 0.5675 - val_wine_type_accuracy: 0.9949
# Epoch 166/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2736 - wine_quality_loss: 0.2566 - wine_type_loss: 0.0171 - wine_quality_root_mean_squared_error: 0.5065 - wine_type_accuracy: 0.9965 - val_loss: 0.3382 - val_wine_quality_loss: 0.3140 - val_wine_type_loss: 0.0242 - val_wine_quality_root_mean_squared_error: 0.5604 - val_wine_type_accuracy: 0.9949
# Epoch 167/180
# 99/99 [==============================] - 1s 8ms/step - loss: 0.2720 - wine_quality_loss: 0.2551 - wine_type_loss: 0.0170 - wine_quality_root_mean_squared_error: 0.5050 - wine_type_accuracy: 0.9965 - val_loss: 0.3334 - val_wine_quality_loss: 0.3093 - val_wine_type_loss: 0.0242 - val_wine_quality_root_mean_squared_error: 0.5561 - val_wine_type_accuracy: 0.9949
# Epoch 168/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2723 - wine_quality_loss: 0.2554 - wine_type_loss: 0.0169 - wine_quality_root_mean_squared_error: 0.5054 - wine_type_accuracy: 0.9965 - val_loss: 0.3336 - val_wine_quality_loss: 0.3093 - val_wine_type_loss: 0.0242 - val_wine_quality_root_mean_squared_error: 0.5562 - val_wine_type_accuracy: 0.9949
# Epoch 169/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.2718 - wine_quality_loss: 0.2549 - wine_type_loss: 0.0169 - wine_quality_root_mean_squared_error: 0.5049 - wine_type_accuracy: 0.9965 - val_loss: 0.3358 - val_wine_quality_loss: 0.3116 - val_wine_type_loss: 0.0242 - val_wine_quality_root_mean_squared_error: 0.5582 - val_wine_type_accuracy: 0.9949
# Epoch 170/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2711 - wine_quality_loss: 0.2543 - wine_type_loss: 0.0168 - wine_quality_root_mean_squared_error: 0.5043 - wine_type_accuracy: 0.9965 - val_loss: 0.3335 - val_wine_quality_loss: 0.3093 - val_wine_type_loss: 0.0242 - val_wine_quality_root_mean_squared_error: 0.5561 - val_wine_type_accuracy: 0.9949
# Epoch 171/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.2709 - wine_quality_loss: 0.2542 - wine_type_loss: 0.0167 - wine_quality_root_mean_squared_error: 0.5042 - wine_type_accuracy: 0.9965 - val_loss: 0.3334 - val_wine_quality_loss: 0.3092 - val_wine_type_loss: 0.0243 - val_wine_quality_root_mean_squared_error: 0.5560 - val_wine_type_accuracy: 0.9949
# Epoch 172/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2703 - wine_quality_loss: 0.2536 - wine_type_loss: 0.0167 - wine_quality_root_mean_squared_error: 0.5036 - wine_type_accuracy: 0.9965 - val_loss: 0.3349 - val_wine_quality_loss: 0.3107 - val_wine_type_loss: 0.0242 - val_wine_quality_root_mean_squared_error: 0.5574 - val_wine_type_accuracy: 0.9949
# Epoch 173/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2701 - wine_quality_loss: 0.2534 - wine_type_loss: 0.0166 - wine_quality_root_mean_squared_error: 0.5034 - wine_type_accuracy: 0.9965 - val_loss: 0.3363 - val_wine_quality_loss: 0.3121 - val_wine_type_loss: 0.0241 - val_wine_quality_root_mean_squared_error: 0.5587 - val_wine_type_accuracy: 0.9949
# Epoch 174/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2705 - wine_quality_loss: 0.2539 - wine_type_loss: 0.0166 - wine_quality_root_mean_squared_error: 0.5039 - wine_type_accuracy: 0.9965 - val_loss: 0.3403 - val_wine_quality_loss: 0.3162 - val_wine_type_loss: 0.0242 - val_wine_quality_root_mean_squared_error: 0.5623 - val_wine_type_accuracy: 0.9949
# Epoch 175/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.2698 - wine_quality_loss: 0.2532 - wine_type_loss: 0.0166 - wine_quality_root_mean_squared_error: 0.5032 - wine_type_accuracy: 0.9965 - val_loss: 0.3432 - val_wine_quality_loss: 0.3190 - val_wine_type_loss: 0.0242 - val_wine_quality_root_mean_squared_error: 0.5648 - val_wine_type_accuracy: 0.9949
# Epoch 176/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.2687 - wine_quality_loss: 0.2522 - wine_type_loss: 0.0165 - wine_quality_root_mean_squared_error: 0.5022 - wine_type_accuracy: 0.9965 - val_loss: 0.3313 - val_wine_quality_loss: 0.3073 - val_wine_type_loss: 0.0241 - val_wine_quality_root_mean_squared_error: 0.5543 - val_wine_type_accuracy: 0.9949
# Epoch 177/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2691 - wine_quality_loss: 0.2527 - wine_type_loss: 0.0164 - wine_quality_root_mean_squared_error: 0.5027 - wine_type_accuracy: 0.9965 - val_loss: 0.3339 - val_wine_quality_loss: 0.3098 - val_wine_type_loss: 0.0241 - val_wine_quality_root_mean_squared_error: 0.5566 - val_wine_type_accuracy: 0.9949
# Epoch 178/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.2694 - wine_quality_loss: 0.2531 - wine_type_loss: 0.0164 - wine_quality_root_mean_squared_error: 0.5031 - wine_type_accuracy: 0.9965 - val_loss: 0.3351 - val_wine_quality_loss: 0.3109 - val_wine_type_loss: 0.0242 - val_wine_quality_root_mean_squared_error: 0.5575 - val_wine_type_accuracy: 0.9949
# Epoch 179/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.2670 - wine_quality_loss: 0.2507 - wine_type_loss: 0.0163 - wine_quality_root_mean_squared_error: 0.5007 - wine_type_accuracy: 0.9965 - val_loss: 0.3339 - val_wine_quality_loss: 0.3097 - val_wine_type_loss: 0.0242 - val_wine_quality_root_mean_squared_error: 0.5565 - val_wine_type_accuracy: 0.9949
# Epoch 180/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2678 - wine_quality_loss: 0.2515 - wine_type_loss: 0.0163 - wine_quality_root_mean_squared_error: 0.5015 - wine_type_accuracy: 0.9965 - val_loss: 0.3390 - val_wine_quality_loss: 0.3149 - val_wine_type_loss: 0.0241 - val_wine_quality_root_mean_squared_error: 0.5612 - val_wine_type_accuracy: 0.9949

# %%
utils.test_history(history)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-77-bb2fa200c0ad> in <cell line: 1>()
# ----> 1 utils.test_history(history)
#
# /content/TensorFlow-Advanced-Techniques-Specialization/Course 1 - Custom Models, Layers, and Loss Functions with TensorFlow/Week 1/utils.py in test_history(history)
#     332         {
#     333             "name": "params_samples_check",
# --> 334             "result": vars_history['params']['samples'],
#     335             "expected": 3155,
#     336             "error_message": 'Training samples is incorrect. Please check arguments to model.fit().'
#
# KeyError: 'samples'

# %%
# Gather the training metrics
loss, wine_quality_loss, wine_type_loss, wine_quality_rmse, wine_type_accuracy = model.evaluate(x=norm_val_X, y=val_Y)

print()
print(f'loss: {loss}')
print(f'wine_quality_loss: {wine_quality_loss}')
print(f'wine_type_loss: {wine_type_loss}')
print(f'wine_quality_rmse: {wine_quality_rmse}')
print(f'wine_type_accuracy: {wine_type_accuracy}')

# EXPECTED VALUES
# ~ 0.30 - 0.38
# ~ 0.30 - 0.38
# ~ 0.018 - 0.030
# ~ 0.50 - 0.62
# ~ 0.97 - 1.0

# Example:
#0.3657050132751465
#0.3463745415210724
#0.019330406561493874
#0.5885359048843384
#0.9974651336669922
# Out:
# 25/25 [==============================] - 0s 1ms/step - loss: 0.3390 - wine_quality_loss: 0.3149 - wine_type_loss: 0.0241 - wine_quality_root_mean_squared_error: 0.5612 - wine_type_accuracy: 0.9949
#
# loss: 0.3390202820301056
# wine_quality_loss: 0.3149007558822632
# wine_type_loss: 0.024119488894939423
# wine_quality_rmse: 0.5611602067947388
# wine_type_accuracy: 0.9949302673339844

# %%
#Analyze the Model Performance

predictions = model.predict(norm_test_X)
quality_pred = predictions[0]
type_pred = predictions[1]
# Out:
# 31/31 [==============================] - 0s 1ms/step

# %%
print(quality_pred[0])
# Out:
# [5.6379356]

# %%
print(type_pred[0])
print(type_pred[944])
# Out:
# [0.0001013]
# [0.99999976]

# %%
print(quality_pred[1])
# Out:
# [5.762682]

# %%
#Plot Utilities

def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0,ylim)
    plt.plot(history.history[metric_name],color='blue',label=metric_name)
    plt.plot(history.history['val_' + metric_name],color='green',label='val_' + metric_name)

def plot_confusion_matrix(y_true, y_pred, title='', labels=[0,1]):
    cm = confusion_matrix(y_true, y_pred)
    fig = plt.figure()
    ax = fig.add_subplot(111)
    cax = ax.matshow(cm)
    plt.title('Confusion matrix of the classifier')
    fig.colorbar(cax)
    ax.set_xticklabels([''] + labels)
    ax.set_yticklabels([''] + labels)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    fmt = 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
          plt.text(j, i, format(cm[i, j], fmt),
                  horizontalalignment="center",
                  color="black" if cm[i, j] > thresh else "white")
    plt.show()
  
def plot_diff(y_true, y_pred, title = '' ):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.plot([-100, 100], [-100, 100])
    return plt

# %%
#PLots for Metrics
plot_metrics('wine_quality_root_mean_squared_error', 'RMSE', ylim=2)

# %%
plot_metrics('wine_type_loss', 'Wine Type Loss', ylim=0.2)

# %%
#Plots for Confusion Matrix

plot_confusion_matrix(test_Y[1], np.round(type_pred), title='Wine Type', labels = [0, 1])
# Out:
# <ipython-input-83-dd461aaae5ab>:16: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([''] + labels)
# <ipython-input-83-dd461aaae5ab>:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([''] + labels)

# %%
scatter_plot = plot_diff(test_Y[0], quality_pred, title='Type')
