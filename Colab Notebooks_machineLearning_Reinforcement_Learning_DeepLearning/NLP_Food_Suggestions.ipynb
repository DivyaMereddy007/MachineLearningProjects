# %%
#test mounting drive
from google.colab import drive
drive.mount('/content/grive')
# Out:
# Mounted at /content/grive

# %%
import pandas as pd
import pickle
import numpy as np

# %%
data=pd.read_csv('/Users/divyamereddy/Documents/GitHub/ML_Research_Projects/Home_Automation/Food_Suggestion/Data/RecipeNLG_dataset.csv')

# %%
#!pip install opendatasets --upgrade
import opendatasets as od
dataset_url = 'https://www.kaggle.com/tunguz/us-elections-dataset'
od.download(dataset_url)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: divyamereddy007
# Your Kaggle Key: ··········
# Downloading us-elections-dataset.zip to ./us-elections-dataset
# 100%|██████████| 133k/133k [00:00<00:00, 34.0MB/s]
