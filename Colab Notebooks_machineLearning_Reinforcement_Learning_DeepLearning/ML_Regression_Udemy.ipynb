# %%
#Simple linear regression

# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt

# %%
#Import the data set
dataset=pd.read_csv("Salary_Data.csv")
x=dataset.iloc[:,:-1].values
y=dataset.iloc[:-1].values
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-e14e9b074a82> in <module>
#       1 #Import the data set
# ----> 2 dataset=pd.read_csv("Salary_Data.csv")
#       3 x=dataset.iloc[:,:-1]
#       4 y=dataset.iloc[:-1]
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
from pandas.core.common import random_state
#spliting the data set
from sklear.model_selection uimport train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
#Traiing simple linear regression
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X_Train,y_train)

# %%
#predict the results
y_pred=regressor.predict(X_test)

# %%
#Validate

# %%
#visuvalize Train & Test data

# %%
plt.scatter(X_train,y_train, color='red')
plt.plot(X_train, regressor.predict(X_train),color='blue')
plt.title('salary vs Experience (TRaining set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d40f7cf08e0d> in <module>
# ----> 1 plt.scatter(X_train,y_train, color='red')
#       2 plt.plot(X_train, regressor.predict(X_train),color='blue')
#       3 plt.title('salary vs Experience (TRaining set)')
#       4 plt.xlabel('Years of Experience')
#       5 plt.ylabel('Salary')
#
# NameError: name 'plt' is not defined

# %%
plt.scatter(X_test,y_test)
plt.plot(X_test,regressor.predict(X_test),color='blue')
plt.title("Salary vs Experience")
plt.xlabel("Years of Experience")
plt.ylabel('Salary')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-1649363e24bc> in <module>
# ----> 1 plt.scatter(X_test,y_test)
#       2 plt.plot(X_test,regressor.predict(X_test),color='blue')
#       3 plt.title("Salary vs Experience")
#       4 plt.xlabel("Years of Experience")
#       5 plt.ylabel('Salary')
#
# NameError: name 'X_test' is not defined

# %%
##muti regression programs

# %%
#import libs
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#import datasets
dataset=pd.read_csv('50_Startups.csv')
X=dataset.ilot[:,:-1].values
y=dataset.iloc[:,:-1].values

# %%
#Startups data

# %%
from tables.table import Col
#Encoding Categorical data
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct=ColumnTransformer(transformers=[('encoder',OneHotEncoder(),[3])],remainder='passthrough')
X=np.array(ct.fit_transform(X))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-48d4df6ff5dc> in <module>
#       4 from sklearn.preprocessing import OneHotEncoder
#       5 ct=ColumnTransformer(transformers=[('encoder',OneHotEncoder(),[3])],remainder='passthrough')
# ----> 6 X=np.array(ct.fit_transform(X))
#
# NameError: name 'np' is not defined

# %%
print(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-1e2a8387e3ee> in <module>
# ----> 1 Print(X)
#
# NameError: name 'Print' is not defined

# %%
#Splitting the datasets into training set and Test set
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-1317850c93ac> in <module>
#       1 #Splitting the datasets into training set and Test set
#       2 from sklearn.model_selection import train_test_split
# ----> 3 X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)
#
# NameError: name 'X' is not defined

# %%
#Training The Multiple Linear Regression Model on 
from sklearn.linear_model import LinearRegression
regressor =LinearRegression()
regressor.fit(X_train,y_train)

# %%
#Predicting the test dataset
y_red=regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1),y_test.reshape(len(y_test),1)),axis=1))

# %%
### polynomial regression

# %%
## SVR Models

# %%
#import librarries
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
#read data
data=pd.read_csv('')
X=data.iloc[:,1:-1].values
y=data.iloc[:-1].values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4bc87b9d219b> in <module>
#       1 #read data
# ----> 2 data=pd.read_csv('')
#       3 X=data[:,1:-1].values
#       4 y=data[:-1].values
#
# NameError: name 'pd' is not defined

# %%
#Feature scaling 
# from sklearn.preprocessing import train_test_split
# train_X,test_X,tarin_y,test_y=train_test_split(X,y)
#We are
